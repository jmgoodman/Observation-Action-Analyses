# %% [markdown]
# # Imports

# %%
import os
while 'pythonfigures' not in os.listdir():
    os.chdir('..')

# %%
from pythonfigures.datapartition import DataPartitioner
from pythonfigures.neuraldatabase import Query
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import normalize
from scipy.linalg import subspace_angles, null_space, orth
from numpy.linalg import norm

import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import iplot
from plotly.subplots import make_subplots

from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import colors

from typing import Optional

import re
import json

import colorsys

from random import choices

# %% [markdown]
# # Step 1: active-passive & visuomotor indices (forget about congruence)

# %%
# a string parser
def mysplit(s):
    head = s.rstrip('0123456789')
    tail = s[len(head):]
    return head, tail

animal,_ = mysplit('Zara64')
print(animal)
# Out:
# Zara

# %%
# set up a list of data-getters
# note: ignore Zara68. It's got too few units and is too temporally close to Zara70 in any case
sessions  = ['Zara64','Zara70','Moe46','Moe50']
areas     = ['AIP','F5','M1']

apidict = dict()
vmidict = dict()

for session in sessions:
    # actually, we made the decision to pool animals. neat!
    # animal,_ = mysplit(session)
    for area in areas:
        print(f'{session} {area}')
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['cue onset','hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','object','grip','alignment'])
        
        
        
        # get passive-active indices
        df         = dp.readQuery({'context','alignment','grip'})
        df_active  = df[(df['alignment']=='hold onset') & (df['context']=='active')]
        df_passive = df[(df['alignment']=='hold onset') & (df['context']=='passive')]
        
        active_range   = df_active[dp.get('neuronColumnNames')].max() - df_active[dp.get('neuronColumnNames')].min()
        passive_range  = df_passive[dp.get('neuronColumnNames')].max() - df_passive[dp.get('neuronColumnNames')].min()
        
        API            = (active_range - passive_range) / (active_range + passive_range)
        
        if area not in apidict:
            apidict[area] = API.add_suffix(f"_{session}_{area}")
        else:
            apidict[area] = pd.concat((apidict[area],API.add_suffix(f"_{session}_{area}")))
            
        # get visuomotor indices
        df         = dp.readQuery({'context','alignment','object'})
        df_visual  = df[(df['alignment']=='cue onset') & (df['context']=='active')]
        df_motor   = df[(df['alignment']=='hold onset') & (df['context']=='active')]
        
        visual_range   = df_visual[dp.get('neuronColumnNames')].max() - df_visual[dp.get('neuronColumnNames')].min()
        motor_range    = df_motor[dp.get('neuronColumnNames')].max() - df_motor[dp.get('neuronColumnNames')].min()
        
        VMI            = (visual_range - motor_range) / (visual_range + motor_range)
        
        if area not in vmidict:
            vmidict[area] = VMI.add_suffix(f"_{session}_{area}")
        else:
            vmidict[area] = pd.concat((vmidict[area],VMI.add_suffix(f"_{session}_{area}")))
# Out:
# Zara64 AIP
# Zara64 F5
# Zara64 M1
# Zara70 AIP
# Zara70 F5
# Zara70 M1
# Moe46 AIP
# Moe46 F5
# Moe46 M1
# Moe50 AIP
# Moe50 F5
# Moe50 M1

# %%
# now plot!
df_list = []
for area in areas:
    api = apidict[area]
    vmi = vmidict[area]
    
    df_list += [pd.DataFrame({'API':api,'VMI':vmi,'area':[area for x in range(len(api))]})]
    
dfcombo = pd.concat( tuple(df_list) )
print(dfcombo)

histhandle = make_subplots(rows=1,cols=2)
colors = pd.read_csv(os.path.join('pythonfigures','colors.csv'))
shift = -.001
maxfreq = 0
for area in areas:
    df_ = dfcombo[dfcombo['area']==area]
    api     = df_['API'].to_numpy()
    vmi     = df_['VMI'].to_numpy()
    bedges  = np.linspace(-1,1,24)
    apihist,_ = np.histogram(api,bins=bedges)
    vmihist,_ = np.histogram(vmi,bins=bedges)
    
    maxfreq = max(maxfreq,max(apihist/sum(apihist)),max(vmihist/sum(vmihist)))
    
    c  = colors[colors["Area"]==area].to_numpy()
    c  = c[0][:3]
    
    # API histogram
    histhandle.add_trace(
        go.Scatter(
            x=bedges+shift,
            y=np.append(apihist/sum(apihist),apihist[-1]/sum(apihist)),
            name=area,
            line={
                'color':f'rgba({c[0]},{c[1]},{c[2]},0.5)',
                'shape':'hv'
            },
        ),
        row=1,
        col=1
    )
    
    # VMI histogram
    histhandle.add_trace(
        go.Scatter(
            x=bedges+shift,
            y=np.append(vmihist/sum(vmihist),vmihist[-1]/sum(vmihist)),
            name=area,
            line={
                'color':f'rgba({c[0]},{c[1]},{c[2]},0.5)',
                'shape':'hv'
            },
        ),
        row=1,
        col=2
    )
    
    shift+=.001

    
# pop back out of the loop
histhandle.update_xaxes(ticks='outside',
                           tickwidth=1,
                           tickcolor='black',
                           ticklen=4,
                           linecolor='rgba(0,0,0,1)',
                           linewidth=1)

histhandle.update_yaxes(ticks='outside',
                               tickwidth=1,
                               tickcolor='black',
                               ticklen=4,
                               linecolor='rgba(0,0,0,1)',
                               linewidth=1
                               )

# guess I gotta go low-level for this
histhandle['layout']['xaxis']['title'] = 'Active-Passive Index'
histhandle['layout']['xaxis2']['title'] = 'Visuomotor Index'
histhandle['layout']['yaxis']['range'] = [-0.001,maxfreq+0.001]
histhandle['layout']['yaxis2']['range'] = [-0.001,maxfreq+0.001]

histhandle.update_layout(
    yaxis_title='Fraction of Neurons',
    plot_bgcolor='rgba(0,0,0,0)' ,
    paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    autosize=False,
    width=1000,
    height=500
)

# I also need to do janky things to make a custom legend, too! wow!
prepend=''
for area in areas:
    c  = colors[colors["Area"]==area].to_numpy()
    c  = c[0][:3]

    histhandle.add_annotation(xref='x domain',
                                     yref='y domain',
                                     x = 1,
                                     y = 1,
                                     text = prepend+area,
                                     showarrow=False,
                                     font={
                                         'color':f'rgba({c[0]},{c[1]},{c[2]},0.7)',
                                         'size':14
                                         },
                                     align='right',
                                     valign='top',
                                     yanchor='top',
                                     xanchor='right',
                                     row=1,
                                     col=2)

    prepend+=' <br>' # needs a space


histhandle.show(renderer="svg")

# now one more scatterplot
scatterhandle = make_subplots(rows=1,cols=1)
for area in areas:
    c  = colors[colors["Area"]==area].to_numpy()
    c  = c[0][:3]
    
    df_ = dfcombo[dfcombo['area']==area]
    api     = df_['API'].to_numpy()
    vmi     = df_['VMI'].to_numpy()
    
    scatterhandle.add_trace(
        go.Scatter(
            x=api,
            y=vmi,
            name=area,
            mode='markers',
            line={
                'color':f'rgba({c[0]},{c[1]},{c[2]},0.3)',
            }
        ),
        row=1,
        col=1
    )
    
# pop back out of the loop
scatterhandle.update_xaxes(ticks='outside',
                           tickwidth=1,
                           tickcolor='black',
                           ticklen=4,
                           linecolor='rgba(0,0,0,1)',
                           linewidth=1)

scatterhandle.update_yaxes(ticks='outside',
                               tickwidth=1,
                               tickcolor='black',
                               ticklen=4,
                               linecolor='rgba(0,0,0,1)',
                               linewidth=1
                               )

# guess I gotta go low-level for this
scatterhandle['layout']['xaxis']['title'] = 'Active-Passive Index'
scatterhandle['layout']['xaxis']['range'] = [-1.001,1.001]
scatterhandle['layout']['yaxis']['title'] = 'Visuomotor Index'
scatterhandle['layout']['yaxis']['range'] = [-1.001,1.001]

scatterhandle.update_layout(
    plot_bgcolor='rgba(0,0,0,0)' ,
    paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    autosize=False,
    width=500,
    height=500
)

# I also need to do janky things to make a custom legend, too! wow!
prepend=''
for area in areas:
    c  = colors[colors["Area"]==area].to_numpy()
    c  = c[0][:3]

    scatterhandle.add_annotation(xref='x domain',
                                     yref='y domain',
                                     x = 1,
                                     y = 1,
                                     text = prepend+area,
                                     showarrow=False,
                                     font={
                                         'color':f'rgba({c[0]},{c[1]},{c[2]},0.7)',
                                         'size':14
                                         },
                                     align='right',
                                     valign='top',
                                     yanchor='top',
                                     xanchor='right',
                                     row=1,
                                     col=1)

    prepend+=' <br>' # needs a space
    
scatterhandle.show(renderer="svg")

# no evidence of clustering here!
# that said, we probably won't be using this plot
# even though it fits perfectly with the story...
# Out:
#                     API       VMI area
# n0_Zara64_AIP -0.234749 -0.505858  AIP
# n1_Zara64_AIP -0.090018 -0.302582  AIP
# n2_Zara64_AIP  0.199991 -0.235940  AIP
# n3_Zara64_AIP -0.102403  0.443993  AIP
# n4_Zara64_AIP -0.149164 -0.197767  AIP
# ...                 ...       ...  ...
# n159_Moe50_M1 -0.183881 -0.330093   M1
# n160_Moe50_M1 -0.954784  0.333299   M1
# n161_Moe50_M1 -0.032158  0.200754   M1
# n162_Moe50_M1 -0.372312 -0.020208   M1
# n163_Moe50_M1  0.482623 -0.660278   M1
#
# [1632 rows x 3 columns]

# %% [markdown]
# # Step 2: Perform orthogonalization and verify it behaves correctly

# %%
# intermission: import your ML Buddy
# nevermind it'll take too long!

# remember: keep it simple!
# just show you can abolish cross-classification with the visual period
# while ALSO preserving within-context grip classification accuracy!

# %%
orthocounts = dict()
for session in sessions:
    orthocounts[session] = dict()
    for area in areas:
        print(f"{session} {area}")
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['cue onset','hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','object','grip','turntable','alignment'])
        
        df = dp.readQuery(0)

        df_vision_trials   = df[(df['alignment']=='cue onset') & (df['time']>0)].groupby(['object','trial'])[dp.get('neuronColumnNames')].aggregate('mean')
        labels             = df_vision_trials.index.get_level_values(0)

        flag          = False
        axesToRemove  = 0
        neurcount     = len(dp.get('neuronColumnNames'))
        pccount       = 30
        nsplits       = 5

        skf     = StratifiedKFold(n_splits=nsplits,shuffle=False)
        splits  = skf.split(np.zeros(len(labels)),labels)
        splits  = list(splits) # store as list to allow it to be used many of time
        PCmdls  = []
        deltamu = []

        # step 1: find the set of axes for each split
        for train_,_ in splits:
            df_vision_agg = df_vision_trials.iloc[train_].groupby(level=[0]).aggregate('mean')
            n_components = min(df_vision_agg.shape) - 1
            PCmdl = PCA(n_components=n_components)
            PCmdl.fit(df_vision_agg.to_numpy())
            PCmdls+=[PCmdl]

            # no delta-mus needed

        # step 2: iterate model fitting
        maxAxesToRemove = PCmdls[0].n_components_
        while not flag:
            correct_count = 0
            chance_count  = 0
            total_count   = len(labels)

            for fold,(train_,test_) in enumerate(splits):
                trainX = df_vision_trials.iloc[train_]
                trainy = labels[train_].to_numpy()

                testX  = df_vision_trials.iloc[test_]
                testy  = labels[test_].to_numpy()

                if axesToRemove > 0:
                    nullSpace = null_space( np.matrix(PCmdls[fold].components_[:axesToRemove,:]) )
                else:
                    nullSpace = np.eye(neurcount)

                # projections
                trainX = trainX.to_numpy() @ nullSpace
                testX  = testX.to_numpy() @ nullSpace

                # no deltamu to get rid of

                # now fit a PC model in the remaining space to make sure LDA input is well-conditioned (this improves cross-validated performance)
                PCmdl = PCA(n_components=pccount)
                trainX = PCmdl.fit_transform(trainX)
                testX  = PCmdl.transform(testX)

                # now we can finally start classifying!
                LDmdl = LDA()
                LDmdl.fit(trainX,trainy)
                yhat = LDmdl.predict(testX)

                correct_count += np.sum(yhat==testy)
                chance_count  += len(testy) * max(LDmdl.priors_)

            correct_rate   = correct_count / total_count
            chance_rate    = chance_count / total_count
            threshold_rate = chance_rate + np.sqrt( chance_rate*(1-chance_rate)/total_count ) # chance + 1 SE

            print(f"    Removed axes = {axesToRemove}")
            print(f"    Accuracy = {correct_rate}")
            print(f"    Chance = {chance_rate}")
            print(f"    Threshold = {threshold_rate}")
            print()

            if correct_rate > threshold_rate and axesToRemove<maxAxesToRemove:
                axesToRemove+=1
            else:
                flag = True

        print(f"    Final result: remove {axesToRemove} axes")
        print()
        print()
        
        orthocounts[session][area] = axesToRemove
# Out:
# Zara64 AIP
#     Removed axes = 0
#     Accuracy = 0.46774193548387094
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 1
#     Accuracy = 0.39919354838709675
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 2
#     Accuracy = 0.30443548387096775
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 3
#     Accuracy = 0.24193548387096775
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 4
#     Accuracy = 0.1875
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 5
#     Accuracy = 0.14516129032258066
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 6
#     Accuracy = 0.11895161290322581
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 7
#     Accuracy = 0.10887096774193548
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 8
#     Accuracy = 0.10685483870967742
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 9
#     Accuracy = 0.10483870967741936
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 10
#     Accuracy = 0.0907258064516129
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Final result: remove 10 axes
#
#
# Zara64 F5
#     Removed axes = 0
#     Accuracy = 0.4213709677419355
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 1
#     Accuracy = 0.3407258064516129
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 2
#     Accuracy = 0.2620967741935484
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 3
#     Accuracy = 0.2217741935483871
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 4
#     Accuracy = 0.1935483870967742
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 5
#     Accuracy = 0.1693548387096774
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 6
#     Accuracy = 0.16532258064516128
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 7
#     Accuracy = 0.12096774193548387
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 8
#     Accuracy = 0.12298387096774194
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 9
#     Accuracy = 0.12903225806451613
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 10
#     Accuracy = 0.09274193548387097
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Final result: remove 10 axes
#
#
# Zara64 M1
#     Removed axes = 0
#     Accuracy = 0.14516129032258066
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 1
#     Accuracy = 0.10685483870967742
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 2
#     Accuracy = 0.0846774193548387
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Final result: remove 2 axes
#
#
# Zara70 AIP
#     Removed axes = 0
#     Accuracy = 0.3860759493670886
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 1
#     Accuracy = 0.2468354430379747
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 2
#     Accuracy = 0.189873417721519
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 3
#     Accuracy = 0.1540084388185654
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 4
#     Accuracy = 0.13924050632911392
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 5
#     Accuracy = 0.12025316455696203
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 6
#     Accuracy = 0.09071729957805907
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Final result: remove 6 axes
#
#
# Zara70 F5
#     Removed axes = 0
#     Accuracy = 0.31645569620253167
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 1
#     Accuracy = 0.2320675105485232
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 2
#     Accuracy = 0.18565400843881857
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 3
#     Accuracy = 0.14767932489451477
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 4
#     Accuracy = 0.12025316455696203
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 5
#     Accuracy = 0.11392405063291139
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 6
#     Accuracy = 0.09915611814345991
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 7
#     Accuracy = 0.0970464135021097
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Final result: remove 7 axes
#
#
# Zara70 M1
#     Removed axes = 0
#     Accuracy = 0.09071729957805907
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Final result: remove 0 axes
#
#
# Moe46 AIP
#     Removed axes = 0
#     Accuracy = 0.5415224913494809
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 1
#     Accuracy = 0.532871972318339
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 2
#     Accuracy = 0.4117647058823529
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 3
#     Accuracy = 0.3027681660899654
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 4
#     Accuracy = 0.2750865051903114
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 5
#     Accuracy = 0.21280276816608998
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 6
#     Accuracy = 0.15570934256055363
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 7
#     Accuracy = 0.12629757785467127
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 8
#     Accuracy = 0.11591695501730104
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 9
#     Accuracy = 0.0726643598615917
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Final result: remove 9 axes
#
#
# Moe46 F5
#     Removed axes = 0
#     Accuracy = 0.2508650519031142
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 1
#     Accuracy = 0.22664359861591696
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 2
#     Accuracy = 0.15570934256055363
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 3
#     Accuracy = 0.1384083044982699
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 4
#     Accuracy = 0.11245674740484429
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 5
#     Accuracy = 0.09515570934256055
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Final result: remove 5 axes
#
#
# Moe46 M1
#     Removed axes = 0
#     Accuracy = 0.13321799307958476
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 1
#     Accuracy = 0.10899653979238755
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Removed axes = 2
#     Accuracy = 0.0726643598615917
#     Chance = 0.08520715547627442
#     Threshold = 0.09681991663292946
#
#     Final result: remove 2 axes
#
#
# Moe50 AIP
#     Removed axes = 0
#     Accuracy = 0.6362038664323374
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 1
#     Accuracy = 0.5852372583479789
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 2
#     Accuracy = 0.4833040421792619
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 3
#     Accuracy = 0.34973637961335674
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#     Removed axes = 4
#     Accuracy = 0.2741652021089631
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 5
#     Accuracy = 0.2601054481546573
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 6
#     Accuracy = 0.20738137082601055
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 7
#     Accuracy = 0.19332161687170474
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 8
#     Accuracy = 0.17223198594024605
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 9
#     Accuracy = 0.14938488576449913
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 10
#     Accuracy = 0.13181019332161686
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 11
#     Accuracy = 0.11775043936731107
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 12
#     Accuracy = 0.1265377855887522
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 13
#     Accuracy = 0.10896309314586995
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 14
#     Accuracy = 0.09490333919156414
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Final result: remove 14 axes
#
#
# Moe50 F5
#     Removed axes = 0
#     Accuracy = 0.22847100175746923
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 1
#     Accuracy = 0.1687170474516696
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 2
#     Accuracy = 0.1265377855887522
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 3
#     Accuracy = 0.10017574692442882
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 4
#     Accuracy = 0.08787346221441125
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Final result: remove 4 axes
#
#
# Moe50 M1
#     Removed axes = 0
#     Accuracy = 0.0913884007029877
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Final result: remove 0 axes

# %%
# armed with our orthocounts dictionary, let's now verify that it successfully abolishes our ability to use movement-period data with a classifier trained on visual data
crossaccs = dict()

for session in sessions:
    crossaccs[session] = dict()
    
    for area in areas:
        print(f"{session} {area}")
        crossaccs[session][area] = dict()
        
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['cue onset','hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','object','grip','turntable','alignment'])
        
        df = dp.readQuery(0)

        df_vision_trials   = df[(df['alignment']=='cue onset') & (df['time']>0)].groupby(['object','trial'],sort=False)[dp.get('neuronColumnNames')].aggregate('mean')
        df_movement_trials = df[(df['alignment']=='hold onset') & (df['time']<0)].groupby(['object','trial'],sort=False)[dp.get('neuronColumnNames')].aggregate('mean')
        labels             = df_vision_trials.index.get_level_values(0)

        flag          = False
        axesToRemove  = 0
        neurcount     = len(dp.get('neuronColumnNames'))
        pccount       = 30
        nsplits       = 5

        skf     = StratifiedKFold(n_splits=nsplits,shuffle=False)
        splits  = skf.split(np.zeros(len(labels)),labels)
        splits  = list(splits) # store as list to allow it to be used many of time
        PCmdls  = []
        deltamu = []

        # step 1: find the set of axes for each split
        for train_,_ in splits:
            df_vision_agg = df_vision_trials.iloc[train_].groupby(level=[0]).aggregate('mean')
            n_components = min(df_vision_agg.shape) - 1
            PCmdl = PCA(n_components=n_components)
            PCmdl.fit(df_vision_agg.to_numpy())
            PCmdls+=[PCmdl]

            # also compute delta-mu
            deltamu += [(df_vision_trials.mean() - df_movement_trials.mean()).to_numpy()]

        # step 2: cross-validated model fitting & evaluation
        idx=0
        for axesToRemove in [0,orthocounts[session][area]]:
            correct_count = 0
            chance_count  = 0
            total_count   = len(labels)

            for fold,(train_,test_) in enumerate(splits):
                trainX = df_vision_trials.iloc[train_]
                trainy = labels[train_].to_numpy()

                testX  = df_movement_trials.iloc[test_]
                testy  = labels[test_].to_numpy()

                if axesToRemove > 0:
                    nullSpace = null_space( np.matrix(PCmdls[fold].components_[:axesToRemove,:]) )
                else:
                    nullSpace = np.eye(neurcount)

                # projections
                trainX = trainX.to_numpy() @ nullSpace
                testX  = testX.to_numpy() @ nullSpace
                
                # deltamu removal
                dmu = deltamu[fold] @ nullSpace
                dmu_null = null_space( np.matrix(dmu) )

                # now fit a PC model in the remaining space to make sure LDA input is well-conditioned (this improves cross-validated performance)
                PCmdl = PCA(n_components=pccount)
                trainX = PCmdl.fit_transform(trainX @ dmu_null)
                testX  = PCmdl.transform(testX @ dmu_null)

                # now we can finally start classifying!
                LDmdl = LDA()
                LDmdl.fit(trainX,trainy)
                yhat = LDmdl.predict(testX)

                correct_count += np.sum(yhat==testy)
                chance_count  += len(testy) * max(LDmdl.priors_)

            correct_rate   = correct_count / total_count
            chance_rate    = chance_count / total_count
            threshold_rate = chance_rate + np.sqrt( chance_rate*(1-chance_rate)/total_count ) # chance + 1 SE
            
            temp = dict()
            temp['correct_count'] = correct_count
            temp['chance_count']  = chance_count
            temp['total_count']   = total_count
            temp['removed_axes']  = axesToRemove
            temp['neuron_count']  = len(dp.get('neuronColumnNames'))
            
            if idx==0:
                crossaccs[session][area]['naive'] = temp
            else:
                crossaccs[session][area]['orthogonalized'] = temp
            
            print(f"    Removed axes = {axesToRemove}")
            print(f"    Number of neurons = {len(dp.get('neuronColumnNames'))}")
            print(f"    Accuracy = {correct_rate}")
            print(f"    Chance = {chance_rate}")
            print(f"    Threshold = {threshold_rate}")
            print()
            idx+=1
# Out:
# Zara64 AIP
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.3487903225806452
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 10
#     Number of neurons = 121
#     Accuracy = 0.08266129032258064
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
# Zara64 F5
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.14516129032258066
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 10
#     Number of neurons = 121
#     Accuracy = 0.0625
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
# Zara64 M1
#     Removed axes = 0
#     Number of neurons = 99
#     Accuracy = 0.125
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
#     Removed axes = 2
#     Number of neurons = 99
#     Accuracy = 0.05443548387096774
#     Chance = 0.08064557166694161
#     Threshold = 0.09287175518355723
#
# Zara70 AIP
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.2721518987341772
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 6
#     Number of neurons = 121
#     Accuracy = 0.09915611814345991
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
# Zara70 F5
#     Removed axes = 0
#     Number of neurons = 108
#     Accuracy = 0.14556962025316456
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 7
#     Number of neurons = 108
#     Accuracy = 0.08438818565400844
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
# Zara70 M1
#     Removed axes = 0
#     Number of neurons = 183
#     Accuracy = 0.07805907172995781
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
#     Removed axes = 0
#     Number of neurons = 183
#     Accuracy = 0.07805907172995781
#     Chance = 0.08438865441215677
#     Threshold = 0.09715623015443184
#
# Moe46 AIP
#     Removed axes = 0
#     Number of neurons = 102
#     Accuracy = 0.33217993079584773
#     Chance = 0.08520248052559515
#     Threshold = 0.09681495277874794
#
#     Removed axes = 9
#     Number of neurons = 102
#     Accuracy = 0.07785467128027682
#     Chance = 0.08520248052559515
#     Threshold = 0.09681495277874794
#
# Moe46 F5
#     Removed axes = 0
#     Number of neurons = 191
#     Accuracy = 0.15051903114186851
#     Chance = 0.08520248052559515
#     Threshold = 0.09681495277874794
#
#     Removed axes = 5
#     Number of neurons = 191
#     Accuracy = 0.09688581314878893
#     Chance = 0.08520248052559515
#     Threshold = 0.09681495277874794
#
# Moe46 M1
#     Removed axes = 0
#     Number of neurons = 149
#     Accuracy = 0.1245674740484429
#     Chance = 0.08520248052559515
#     Threshold = 0.09681495277874794
#
#     Removed axes = 2
#     Number of neurons = 149
#     Accuracy = 0.06228373702422145
#     Chance = 0.08520248052559515
#     Threshold = 0.09681495277874794
#
# Moe50 AIP
#     Removed axes = 0
#     Number of neurons = 67
#     Accuracy = 0.4428822495606327
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 14
#     Number of neurons = 67
#     Accuracy = 0.06502636203866433
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
# Moe50 F5
#     Removed axes = 0
#     Number of neurons = 206
#     Accuracy = 0.12126537785588752
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 4
#     Number of neurons = 206
#     Accuracy = 0.07205623901581722
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
# Moe50 M1
#     Removed axes = 0
#     Number of neurons = 164
#     Accuracy = 0.08963093145869948
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915
#
#     Removed axes = 0
#     Number of neurons = 164
#     Accuracy = 0.08963093145869948
#     Chance = 0.08348011098450465
#     Threshold = 0.09507606067846915

# %%
# get the data ready for plotting
# x = before
# y = after

pre_     = []
post_    = []
pre_se   = []
post_se  = []
chance   = []
session_ = []
animal   = []
area_    = []

for session in crossaccs:
    for area in crossaccs[session]:
        temp = crossaccs[session][area]
        pre_ +=[temp['naive']['correct_count']/temp['naive']['total_count']]
        post_+=[temp['orthogonalized']['correct_count']/temp['orthogonalized']['total_count']]
        pre_se+=[( pre_[-1]*(1-pre_[-1])/temp['naive']['total_count'] )]
        post_se+=[( post_[-1]*(1-post_[-1])/temp['orthogonalized']['total_count'] )] # keep it squared so you can sum them
        chance+=[temp['naive']['chance_count'] / temp['naive']['total_count']] # chance should be the same across both naive & orthogonalized
        session_+=[session]
        
        an,_ = mysplit(session)
        
        animal+=[an]
        area_+=[area]
        
dd = {'naive':pre_,
      'orthogonalized':post_,
      'naive_se2':pre_se,
      'orthogonalized_se2':post_se,
      'chance':chance,
      'session':session_,
      'animal':animal,
      'area':area_}

df = pd.DataFrame(dd)

print(df)



mu = df.groupby(['area'])[['naive','orthogonalized','naive_se2','orthogonalized_se2']].mean()
se = df.groupby(['area'])[['naive','orthogonalized']].sem()
print(mu)
print(se)
# Out:
#        naive  orthogonalized  naive_se2  orthogonalized_se2    chance session  \
# 0   0.348790        0.082661   0.000458            0.000153  0.080646  Zara64
# 1   0.145161        0.062500   0.000250            0.000118  0.080646  Zara64
# 2   0.125000        0.054435   0.000221            0.000104  0.080646  Zara64
# 3   0.272152        0.099156   0.000418            0.000188  0.084389  Zara70
# 4   0.145570        0.084388   0.000262            0.000163  0.084389  Zara70
# 5   0.078059        0.078059   0.000152            0.000152  0.084389  Zara70
# 6   0.332180        0.077855   0.000384            0.000124  0.085202   Moe46
# 7   0.150519        0.096886   0.000221            0.000151  0.085202   Moe46
# 8   0.124567        0.062284   0.000189            0.000101  0.085202   Moe46
# 9   0.442882        0.065026   0.000434            0.000107  0.083480   Moe50
# 10  0.121265        0.072056   0.000187            0.000118  0.083480   Moe50
# 11  0.089631        0.089631   0.000143            0.000143  0.083480   Moe50
#
#    animal area
# 0    Zara  AIP
# 1    Zara   F5
# 2    Zara   M1
# 3    Zara  AIP
# 4    Zara   F5
# 5    Zara   M1
# 6     Moe  AIP
# 7     Moe   F5
# 8     Moe   M1
# 9     Moe  AIP
# 10    Moe   F5
# 11    Moe   M1
#          naive  orthogonalized  naive_se2  orthogonalized_se2
# area
# AIP   0.349001        0.081175   0.000423            0.000143
# F5    0.140629        0.078958   0.000230            0.000138
# M1    0.104314        0.071102   0.000176            0.000125
#          naive  orthogonalized
# area
# AIP   0.035358        0.007055
# F5    0.006568        0.007469
# M1    0.012052        0.007891

# %%
# and plot
fig = go.Figure()
# fig.full_figure_for_development()
fig.add_trace(go.Bar(
    name='Naive',
    marker_color='rgba(26, 118, 255, 0.7)',
    x=[0,1,2], y=mu['naive'].to_list(),
    error_y=dict(type='data', array=se['naive'].to_list())
))
fig.add_trace(go.Bar(
    name='Orthogonalized',
    marker_color='rgba(55, 83, 109, 0.7)',
    x=[0,1,2], y=mu['orthogonalized'].to_list(),
    error_y=dict(type='data', array=se['orthogonalized'].to_list())
))

fig.update_xaxes(ticks='outside',
                           tickwidth=1,
                           tickcolor='black',
                           ticklen=4,
                           linecolor='rgba(0,0,0,1)',
                           linewidth=1,
                           showgrid=False)

fig.update_yaxes(ticks='outside',
                               tickwidth=1,
                               tickcolor='black',
                               ticklen=4,
                               linecolor='rgba(0,0,0,1)',
                               linewidth=1,
                               showgrid=False
                               )

# guess I gotta go low-level for this
fig['layout']['xaxis']['title'] = 'Cortical Area'
fig['layout']['xaxis']['range'] = [-0.5, 2.5]
fig['layout']['yaxis']['title'] = 'Cross-Classification Accuracy'
fig['layout']['xaxis']['ticktext'] = ['AIP','F5','M1']
fig['layout']['xaxis']['tickvals'] = [0,1,2]

fig.add_trace(
    go.Scatter(
        x=[-0.5,2.5],
        y=[df['chance'].mean() for _ in range(2)],
        name='chance',
        mode='lines',
        line={
            'color':f'rgba(0,0,0,0.5)',
            'dash':'dash'
        }
    ),
)

fig.update_layout(barmode='group',
    plot_bgcolor='rgba(0,0,0,0)' ,
    paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    autosize=False,
    width=500,
    height=500)

# I also need to do janky things to make a custom legend, too! wow!

colors = ['rgba(26, 118, 255, 0.7)','rgba(55, 83, 109, 0.7)']
prepend=''
for idx,legent in enumerate(['Naive','Orthogonalized']):
    c  = colors[idx]

    fig.add_annotation(xref='x domain',
                                     yref='y domain',
                                     x = 1,
                                     y = 1,
                                     text = prepend+legent,
                                     showarrow=False,
                                     font={
                                         'color':c,
                                         'size':14
                                         },
                                     align='right',
                                     valign='top',
                                     yanchor='top',
                                     xanchor='right')

    prepend+=' <br>' # needs a space
    
fig.show(renderer="svg")
fig.write_image(os.path.join('figs','Vision_Movement_Cross.svg'))

# %%
# now, self-classification
selfaccs = dict()

for session in sessions:
    selfaccs[session] = dict()
    
    for area in areas:
        selfaccs[session][area] = dict()
        
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['cue onset','hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','object','grip','turntable','alignment'])
        
        df = dp.readQuery(0)
        df['turntable'] = df['turntable'] // 10
        
        
        df_vision_trials   = df[(df['alignment']=='cue onset') & (df['time']>0)].groupby(['context','turntable','object','trial'],sort=False)[dp.get('neuronColumnNames')].aggregate('mean')
        df_movement_trials = df[(df['alignment']=='hold onset') & (df['time']<0)].groupby(['context','turntable','grip','trial'],sort=False)[dp.get('neuronColumnNames')].aggregate('mean')
        
        df_vision_trials
        
        # okay, let's iterate through contexts
        for context in ['active','passive']:
            print(f"{session} {area} {context}")
            selfaccs[session][area][context] = dict()
            
            # extract the context (and ignore the special turntable to get your chance level under control... but DO leave it in when estimating the subspace spanned by the object vision repertoire)
            df_movement_context  = df_movement_trials.loc[(df_movement_trials.index.get_level_values(0)==context) & (df_movement_trials.index.get_level_values(1)!=9)] # keep the context multiindex level here, too
            df_vision_context    = df_vision_trials.loc[(df_vision_trials.index.get_level_values(0)==context) & (df_vision_trials.index.get_level_values(1)!=9)] # keep the context multiindex level to enable aggregation after concatenation
            df_vision_offcontext = df_vision_trials.loc[(df_vision_trials.index.get_level_values(0)!=context) |  (df_vision_trials.index.get_level_values(1)==9)]
            
            labels = df_movement_context.index.get_level_values(2)
            
            axesToRemove  = 0
            neurcount     = len(dp.get('neuronColumnNames'))
            pccount       = 30
            nsplits       = 5

            skf     = StratifiedKFold(n_splits=nsplits,shuffle=False)
            splits  = skf.split(np.zeros(len(labels)),labels)
            splits  = list(splits) # store as list to allow it to be used many of time
            PCmdls  = []

            # step 1: find the set of axes for each split
            for train_,_ in splits:
                df_vision_cat = pd.concat( (df_vision_context.iloc[train_],df_vision_offcontext) )
                df_vision_agg = df_vision_cat.groupby(level=[1]).aggregate('mean')
                n_components = min(df_vision_agg.shape) - 1
                PCmdl = PCA(n_components=n_components)
                PCmdl.fit(df_vision_agg.to_numpy())
                PCmdls+=[PCmdl]

                # no need for deltamu here

            # step 2: cross-validated model fitting & evaluation
            idx=0
            for axesToRemove in [0,orthocounts[session][area]]:
                correct_count = 0
                chance_count  = 0
                total_count   = len(labels)

                for fold,(train_,test_) in enumerate(splits):
                    trainX = df_movement_context.iloc[train_]
                    trainy = labels[train_].to_numpy()

                    testX  = df_movement_context.iloc[test_]
                    testy  = labels[test_].to_numpy()

                    if axesToRemove > 0:
                        nullSpace = null_space( np.matrix(PCmdls[fold].components_[:axesToRemove,:]) )
                    else:
                        nullSpace = np.eye(neurcount)

                    # projections
                    trainX = trainX.to_numpy() @ nullSpace
                    testX  = testX.to_numpy() @ nullSpace

                    # no deltamu removal needed

                    # now fit a PC model in the remaining space to make sure LDA input is well-conditioned (this improves cross-validated performance)
                    PCmdl = PCA(n_components=pccount)
                    trainX = PCmdl.fit_transform(trainX)
                    testX  = PCmdl.transform(testX)

                    # now we can finally start classifying!
                    LDmdl = LDA()
                    LDmdl.fit(trainX,trainy)
                    yhat = LDmdl.predict(testX)

                    correct_count += np.sum(yhat==testy)
                    chance_count  += len(testy) * max(LDmdl.priors_)

                correct_rate   = correct_count / total_count
                chance_rate    = chance_count / total_count
                threshold_rate = chance_rate + np.sqrt( chance_rate*(1-chance_rate)/total_count ) # chance + 1 SE

                temp = dict()
                temp['correct_count'] = correct_count
                temp['chance_count']  = chance_count
                temp['total_count']   = total_count
                temp['removed_axes']  = axesToRemove
                temp['neuron_count']  = len(dp.get('neuronColumnNames'))

                if idx==0:
                    selfaccs[session][area][context]['naive'] = temp
                else:
                    selfaccs[session][area][context]['orthogonalized'] = temp

                print(f"    Removed axes = {axesToRemove}")
                print(f"    Number of neurons = {len(dp.get('neuronColumnNames'))}")
                print(f"    Accuracy = {correct_rate}")
                print(f"    Chance = {chance_rate}")
                print(f"    Threshold = {threshold_rate}")
                print()
                idx+=1
# Out:
# Zara64 AIP active
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.6779661016949152
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
#     Removed axes = 10
#     Number of neurons = 121
#     Accuracy = 0.5932203389830508
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.38764044943820225
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
#     Removed axes = 10
#     Number of neurons = 121
#     Accuracy = 0.34269662921348315
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.7288135593220338
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
#     Removed axes = 10
#     Number of neurons = 121
#     Accuracy = 0.7457627118644068
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.4044943820224719
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
#     Removed axes = 10
#     Number of neurons = 121
#     Accuracy = 0.43258426966292135
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active
#     Removed axes = 0
#     Number of neurons = 99
#     Accuracy = 0.7005649717514124
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
#     Removed axes = 2
#     Number of neurons = 99
#     Accuracy = 0.6666666666666666
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive
#     Removed axes = 0
#     Number of neurons = 99
#     Accuracy = 0.24719101123595505
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
#     Removed axes = 2
#     Number of neurons = 99
#     Accuracy = 0.21910112359550563
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara70 AIP active
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.7288135593220338
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
#     Removed axes = 6
#     Number of neurons = 121
#     Accuracy = 0.6059322033898306
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive
#     Removed axes = 0
#     Number of neurons = 121
#     Accuracy = 0.3865546218487395
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
#     Removed axes = 6
#     Number of neurons = 121
#     Accuracy = 0.31092436974789917
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active
#     Removed axes = 0
#     Number of neurons = 108
#     Accuracy = 0.597457627118644
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
#     Removed axes = 7
#     Number of neurons = 108
#     Accuracy = 0.5889830508474576
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive
#     Removed axes = 0
#     Number of neurons = 108
#     Accuracy = 0.3067226890756303
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
#     Removed axes = 7
#     Number of neurons = 108
#     Accuracy = 0.29411764705882354
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active
#     Removed axes = 0
#     Number of neurons = 183
#     Accuracy = 0.6271186440677966
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
#     Removed axes = 0
#     Number of neurons = 183
#     Accuracy = 0.6271186440677966
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive
#     Removed axes = 0
#     Number of neurons = 183
#     Accuracy = 0.1722689075630252
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
#     Removed axes = 0
#     Number of neurons = 183
#     Accuracy = 0.1722689075630252
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Moe46 AIP active
#     Removed axes = 0
#     Number of neurons = 102
#     Accuracy = 0.75
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
#     Removed axes = 9
#     Number of neurons = 102
#     Accuracy = 0.7545454545454545
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive
#     Removed axes = 0
#     Number of neurons = 102
#     Accuracy = 0.5576923076923077
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
#     Removed axes = 9
#     Number of neurons = 102
#     Accuracy = 0.5128205128205128
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 F5 active
#     Removed axes = 0
#     Number of neurons = 191
#     Accuracy = 0.8818181818181818
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
#     Removed axes = 5
#     Number of neurons = 191
#     Accuracy = 0.8863636363636364
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 F5 passive
#     Removed axes = 0
#     Number of neurons = 191
#     Accuracy = 0.2564102564102564
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
#     Removed axes = 5
#     Number of neurons = 191
#     Accuracy = 0.2564102564102564
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 M1 active
#     Removed axes = 0
#     Number of neurons = 149
#     Accuracy = 0.740909090909091
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
#     Removed axes = 2
#     Number of neurons = 149
#     Accuracy = 0.7636363636363637
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 M1 passive
#     Removed axes = 0
#     Number of neurons = 149
#     Accuracy = 0.33974358974358976
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
#     Removed axes = 2
#     Number of neurons = 149
#     Accuracy = 0.33974358974358976
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe50 AIP active
#     Removed axes = 0
#     Number of neurons = 67
#     Accuracy = 0.8215962441314554
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
#     Removed axes = 14
#     Number of neurons = 67
#     Accuracy = 0.755868544600939
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 AIP passive
#     Removed axes = 0
#     Number of neurons = 67
#     Accuracy = 0.5774647887323944
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
#     Removed axes = 14
#     Number of neurons = 67
#     Accuracy = 0.5352112676056338
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active
#     Removed axes = 0
#     Number of neurons = 206
#     Accuracy = 0.9107981220657277
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
#     Removed axes = 4
#     Number of neurons = 206
#     Accuracy = 0.9154929577464789
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive
#     Removed axes = 0
#     Number of neurons = 206
#     Accuracy = 0.3286384976525822
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
#     Removed axes = 4
#     Number of neurons = 206
#     Accuracy = 0.3380281690140845
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active
#     Removed axes = 0
#     Number of neurons = 164
#     Accuracy = 0.7652582159624414
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
#     Removed axes = 0
#     Number of neurons = 164
#     Accuracy = 0.7652582159624414
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive
#     Removed axes = 0
#     Number of neurons = 164
#     Accuracy = 0.2300469483568075
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
#     Removed axes = 0
#     Number of neurons = 164
#     Accuracy = 0.2300469483568075
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245

# %%
# prep the data for plotting

# get the data ready for plotting
# x = before
# y = after

pre_     = []
post_    = []
pre_se   = []
post_se  = []
chance   = []
session_ = []
animal   = []
area_    = []
context_ = []

for session in selfaccs:
    for area in selfaccs[session]:
        for context in selfaccs[session][area]:
            temp = selfaccs[session][area][context]
            pre_ +=[temp['naive']['correct_count']/temp['naive']['total_count']]
            post_+=[temp['orthogonalized']['correct_count']/temp['orthogonalized']['total_count']]
            pre_se+=[( pre_[-1]*(1-pre_[-1])/temp['naive']['total_count'] )]
            post_se+=[( post_[-1]*(1-post_[-1])/temp['orthogonalized']['total_count'] )] # keep it squared so you can sum them
            chance+=[temp['naive']['chance_count'] / temp['naive']['total_count']] # chance should be the same across both naive & orthogonalized
            session_+=[session]

            an,_ = mysplit(session)

            animal+=[an]
            area_+=[area]
            context_+=[context]
        
dd = {'naive':pre_,
      'orthogonalized':post_,
      'naive_se2':pre_se,
      'orthogonalized_se2':post_se,
      'chance':chance,
      'session':session_,
      'animal':animal,
      'area':area_,
      'context':context_}

df = pd.DataFrame(dd)

print(df)



mu = df.groupby(['area','context'])[['naive','orthogonalized','naive_se2','orthogonalized_se2']].mean()
se = df.groupby(['area','context'])[['naive','orthogonalized']].sem()
print(mu)
print(se)
# Out:
#        naive  orthogonalized  naive_se2  orthogonalized_se2    chance session  \
# 0   0.677966        0.593220   0.001233            0.001363  0.220332  Zara64
# 1   0.387640        0.342697   0.001334            0.001265  0.168549  Zara64
# 2   0.728814        0.745763   0.001117            0.001071  0.220332  Zara64
# 3   0.404494        0.432584   0.001353            0.001379  0.168549  Zara64
# 4   0.700565        0.666667   0.001185            0.001255  0.220332  Zara64
# 5   0.247191        0.219101   0.001045            0.000961  0.168549  Zara64
# 6   0.728814        0.605932   0.000837            0.001012  0.169495  Zara70
# 7   0.386555        0.310924   0.000996            0.000900  0.126055  Zara70
# 8   0.597458        0.588983   0.001019            0.001026  0.169495  Zara70
# 9   0.306723        0.294118   0.000893            0.000872  0.126055  Zara70
# 10  0.627119        0.627119   0.000991            0.000991  0.169495  Zara70
# 11  0.172269        0.172269   0.000599            0.000599  0.126055  Zara70
# 12  0.750000        0.754545   0.000852            0.000842  0.222727   Moe46
# 13  0.557692        0.512821   0.001581            0.001602  0.230794   Moe46
# 14  0.881818        0.886364   0.000474            0.000458  0.222727   Moe46
# 15  0.256410        0.256410   0.001222            0.001222  0.230794   Moe46
# 16  0.740909        0.763636   0.000873            0.000820  0.222727   Moe46
# 17  0.339744        0.339744   0.001438            0.001438  0.230794   Moe46
# 18  0.821596        0.755869   0.000688            0.000866  0.225389   Moe50
# 19  0.577465        0.535211   0.001146            0.001168  0.164326   Moe50
# 20  0.910798        0.915493   0.000381            0.000363  0.225389   Moe50
# 21  0.328638        0.338028   0.001036            0.001051  0.164326   Moe50
# 22  0.765258        0.765258   0.000843            0.000843  0.225389   Moe50
# 23  0.230047        0.230047   0.000832            0.000832  0.164326   Moe50
#
#    animal area  context
# 0    Zara  AIP   active
# 1    Zara  AIP  passive
# 2    Zara   F5   active
# 3    Zara   F5  passive
# 4    Zara   M1   active
# 5    Zara   M1  passive
# 6    Zara  AIP   active
# 7    Zara  AIP  passive
# 8    Zara   F5   active
# 9    Zara   F5  passive
# 10   Zara   M1   active
# 11   Zara   M1  passive
# 12    Moe  AIP   active
# 13    Moe  AIP  passive
# 14    Moe   F5   active
# 15    Moe   F5  passive
# 16    Moe   M1   active
# 17    Moe   M1  passive
# 18    Moe  AIP   active
# 19    Moe  AIP  passive
# 20    Moe   F5   active
# 21    Moe   F5  passive
# 22    Moe   M1   active
# 23    Moe   M1  passive
#                  naive  orthogonalized  naive_se2  orthogonalized_se2
# area context
# AIP  active   0.744594        0.677392   0.000903            0.001021
#      passive  0.477338        0.425413   0.001264            0.001234
# F5   active   0.779722        0.784151   0.000748            0.000730
#      passive  0.324066        0.330285   0.001126            0.001131
# M1   active   0.708463        0.705670   0.000973            0.000978
#      passive  0.247313        0.240290   0.000979            0.000957
#                  naive  orthogonalized
# area context
# AIP  active   0.029787        0.045002
#      passive  0.052257        0.057479
# F5   active   0.072696        0.074868
#      passive  0.030778        0.037959
# M1   active   0.030218        0.034884
#      passive  0.034729        0.035440

# %%
# and plot

# iterate through contexts
truenames  = ['VGG','Observation']
truecolors = [['rgba(255, 118, 26, 0.7)','rgba(109, 83, 55, 0.7)'],
              ['rgba(26, 200, 118, 0.7)','rgba(55, 109, 83, 0.7)']]
for idx,context in enumerate(['active','passive']):
    fig = go.Figure()
    # fig.full_figure_for_development()
    fig.add_trace(go.Bar(
        name='Naive',
        marker_color=truecolors[idx][0],
        x=[0,1,2], y=mu['naive'].loc[:,context].to_list(),
        error_y=dict(type='data', array=se['naive'].loc[:,context].to_list())
    ))
    fig.add_trace(go.Bar(
        name='Orthogonalized',
        marker_color=truecolors[idx][1],
        x=[0,1,2], y=mu['orthogonalized'].loc[:,context].to_list(),
        error_y=dict(type='data', array=se['orthogonalized'].loc[:,context].to_list())
    ))

    fig.update_xaxes(ticks='outside',
                               tickwidth=1,
                               tickcolor='black',
                               ticklen=4,
                               linecolor='rgba(0,0,0,1)',
                               linewidth=1,
                               showgrid=False)

    fig.update_yaxes(ticks='outside',
                                   tickwidth=1,
                                   tickcolor='black',
                                   ticklen=4,
                                   linecolor='rgba(0,0,0,1)',
                                   linewidth=1,
                                   showgrid=False
                                   )

    # guess I gotta go low-level for this
    fig['layout']['xaxis']['title'] = 'Cortical Area'
    fig['layout']['xaxis']['range'] = [-0.5, 2.5]
    fig['layout']['yaxis']['title'] = f'{truenames[idx]} Classification Accuracy'
    fig['layout']['yaxis']['range'] = [0, 1]
    fig['layout']['xaxis']['ticktext'] = ['AIP','F5','M1']
    fig['layout']['xaxis']['tickvals'] = [0,1,2]

    fig.add_trace(
        go.Scatter(
            x=[-0.5,2.5],
            y=[df['chance'].loc[df['context']==context].mean() for _ in range(2)],
            name='chance',
            mode='lines',
            line={
                'color':f'rgba(0,0,0,0.5)',
                'dash':'dash'
            }
        ),
    )

    fig.update_layout(barmode='group',
        plot_bgcolor='rgba(0,0,0,0)' ,
        paper_bgcolor='rgba(0,0,0,0)',
        showlegend=False,
        autosize=False,
        width=500,
        height=500)

    # I also need to do janky things to make a custom legend, too! wow!

    colors = truecolors[idx]
    prepend=''
    for idx_,legent in enumerate(['Naive','Orthogonalized']):
        c  = colors[idx_]

        fig.add_annotation(xref='x domain',
                                         yref='y domain',
                                         x = 1,
                                         y = 1,
                                         text = prepend+legent,
                                         showarrow=False,
                                         font={
                                             'color':c,
                                             'size':14
                                             },
                                         align='right',
                                         valign='top',
                                         yanchor='top',
                                         xanchor='right')

        prepend+=' <br>' # needs a space

    fig.show(renderer="svg")
    fig.write_image(os.path.join('figs',f'{truenames[idx]}_Self.svg'))

# %% [markdown]
# # Decoding time
# - as in, performing regression to estimate the time relative to movement & hold onset from neural activity
# - then doing CROSS-DECODING to prove it's shared across contexts

# %% [markdown]
# grab the data
#
# no need to do ortho for this or the classification of objects
#
# but you should *probably* do it for the subspace alignment stuff
#
# (btw, grip x time or just grip effects for subspace alignment?)
#
# (meh, focus on just grip effects for now. That's what you use for classification after all, so it's apples-to-apples.)

# %%
# train & test both ways: both leveraging the passive context as a training set, and evaluating its confound potential as a test set
# hmmm... I should really have reaction time stored *somewhere* in this db, no?
# too bad I don't! that'd be a KILLER thing to have...
# oh well, time w.r.t. alignments is still an o.k. thing to decode here
# now, self-classification

timedecs = dict()

for session in sessions:
    timedecs[session] = dict()
    
    for area in areas:
        timedecs[session][area] = dict()
        
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['go cue onset','movement onset','hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','alignment','time'])
        
        df = dp.readQuery(0)
        
        for align in ['go cue onset','movement onset','hold onset']:
            timedecs[session][area][align] = dict()
            
            df_active_trials = df[
                (df['context']=='active') & 
                (df['alignment']==align)
            ]

            df_passive_trials = df[
                (df['context']=='passive') & 
                (df['alignment']==align)
            ]
            
            for testcontext in ['active','passive']:
                print(f"{session} {area} {align} tested on {testcontext}")
                
                if testcontext=='passive':
                    test_t   = df_passive_trials['time']
                    train_df = df_active_trials
                    test_df  = df_passive_trials
                else:
                    test_t   = df_active_trials['time']
                    train_df = df_passive_trials
                    test_df  = df_active_trials

                neurcount     = len(dp.get('neuronColumnNames'))
                pccount       = 30
                nsplits       = 5
                
                # yeah, just raw kfold. would probably be better if I did trial-fold, but honestly, this is 100% just to get the delta-mu problem sorted out. In the end it still has to generalize to a wholly new context with unmatched trials.
                # idea: turntable-fold? Yeah maybe... provided I can account for repertoire shifts
                kf      = KFold(n_splits=nsplits,shuffle=False)
                splits  = kf.split(test_t)
                splits  = list(splits) # store as list to allow it to be used many of time
                deltamu = []

                # step 1: find the deltamu for each split
                # no subspace ortho here
                for train_,_ in splits:
                    train_mu  = train_df[dp.get('neuronColumnNames')].mean()
                    test_mu   = test_df[dp.get('neuronColumnNames')].iloc[train_].mean()
                    delta_mu  = train_mu - test_mu
                    deltamu  += [delta_mu.to_numpy()]

                # step 2: cross-validated model fitting & evaluation
                y        = []
                yhat     = []
                selfR2   = []
                crossR2  = []
                selfVE_regdim  = []
                crossVE_regdim = []
                selfVE_total   = []
                crossVE_total  = []
                

                trainX = train_df[dp.get('neuronColumnNames')]
                trainy = train_df['time']

                for fold,(_,test_) in enumerate(splits):
                    testX  = test_df[dp.get('neuronColumnNames')].iloc[test_]
                    testy  = test_df['time'].iloc[test_]

                    # find the deltamu nullspace to ensure generalization robust to repertoire shifts (i.e., ignore the dimensions that separate the contexts, focus on what they're doing in parallel!)
                    deltanull = null_space( np.matrix(deltamu[fold]) )

                    # now fit a PC model in the remaining space to make sure LDA input is well-conditioned (this improves cross-validated performance)
                    PCmdl = PCA(n_components=pccount)
                    trX_ = PCmdl.fit_transform(trainX.to_numpy() @ deltanull)
                    teX_ = PCmdl.transform(testX.to_numpy() @ deltanull)
                    try_ = trainy.to_numpy()
                    tey_ = testy.to_numpy()

                    # now let's fit an OLS model. Seriously. We bein' basic here.
                    Lregmdl = LinearRegression()
                    Lregmdl.fit(trX_,try_)
                    tey_hat = Lregmdl.predict(teX_)

                    y+=list(tey_)
                    yhat+=list(tey_hat)

                    selfR2  += [Lregmdl.score(trX_,try_)]
                    crossR2 += [Lregmdl.score(teX_,tey_)]
                    
                    # TOTAL VE by the linear regression dimension, with respect to all the neural data within the context (including the ones orthogonalized out by the PCA process)
                    ax = Lregmdl.coef_ / norm( Lregmdl.coef_ )
                    
                    selfVE_regdim  += [np.var( trX_ @ ax )]
                    crossVE_regdim += [np.var( teX_ @ ax )]
                    selfVE_total   += [np.sum( np.var( trainX.to_numpy(),axis=0 ) )]
                    crossVE_total  += [np.sum( np.var( testX.to_numpy(),axis=0 ) )]
                    

                temp = dict()
                # note: y and yhat are the cross-validated values. only selfR2 is a record of the training set performance.
                temp['y'] = y
                temp['yhat'] = yhat
                temp['trainR2'] = selfR2
                temp['testR2'] = crossR2
                temp['trainVE_regdim']  = selfVE_regdim
                temp['testVE_regdim'] = crossVE_regdim
                temp['trainVE_total']   = selfVE_total
                temp['testVE_total']  = crossVE_total
                
                # also save variance explained by the time-decoding axis

                timedecs[session][area][align][testcontext+"_test"] = temp

                print(f"    Number of neurons = {len(dp.get('neuronColumnNames'))}")
                print(f"    Training R^2 = {np.mean(selfR2)}")
                print(f"    Test R^2 = {np.mean(crossR2)}")
                print(f"    Training VE_regdim = {np.mean(selfVE_regdim)}")
                print(f"    Test VE_regdim = {np.mean(crossVE_regdim)}")
                print(f"    Training VE_total = {np.mean(selfVE_total)}")
                print(f"    Test VE_total = {np.mean(crossVE_total)}")
                print()
# Out:
# Zara64 AIP go cue onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.5821653179666626
#     Test R^2 = 0.462539639691554
#     Training VE_regdim = 0.23585380150569857
#     Test VE_regdim = 0.1217688846685202
#     Training VE_total = 3.473825999199002
#     Test VE_total = 3.1012368305580416
#
# Zara64 AIP go cue onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.6300835928904497
#     Test R^2 = 0.4716321980714248
#     Training VE_regdim = 0.16213484797548355
#     Test VE_regdim = 0.08681239582681688
#     Training VE_total = 3.159162030571484
#     Test VE_total = 3.4198342069864287
#
# Zara64 AIP movement onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.7224359973220097
#     Test R^2 = 0.5737146455980707
#     Training VE_regdim = 0.22553373649305147
#     Test VE_regdim = 0.12328231057548714
#     Training VE_total = 4.060135735777288
#     Test VE_total = 3.2745524963568924
#
# Zara64 AIP movement onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.7025749219057591
#     Test R^2 = 0.6200411695942334
#     Training VE_regdim = 0.1748217281060597
#     Test VE_regdim = 0.14296229850501616
#     Training VE_total = 3.332962287832936
#     Test VE_total = 4.004429857456304
#
# Zara64 AIP hold onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.7208395798075002
#     Test R^2 = -0.28121394980732606
#     Training VE_regdim = 0.2723969411864224
#     Test VE_regdim = 0.06721965564359204
#     Training VE_total = 4.1374324809670835
#     Test VE_total = 3.481599123915072
#
# Zara64 AIP hold onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.6569274775066185
#     Test R^2 = -0.3450161088349179
#     Training VE_regdim = 0.15486824483531766
#     Test VE_regdim = 0.04126023799959941
#     Training VE_total = 3.5444694599247115
#     Test VE_total = 4.0749334904672025
#
# Zara64 F5 go cue onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.6738349119257113
#     Test R^2 = 0.6242697647889222
#     Training VE_regdim = 0.21826509339300357
#     Test VE_regdim = 0.19963319516574204
#     Training VE_total = 2.8018382743830803
#     Test VE_total = 4.203735610375729
#
# Zara64 F5 go cue onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.6743194267031271
#     Test R^2 = 0.5657024586428828
#     Training VE_regdim = 0.2355597762244427
#     Test VE_regdim = 0.13290449634346435
#     Training VE_total = 4.287255346661447
#     Test VE_total = 2.758389589389222
#
# Zara64 F5 movement onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.8179508891763344
#     Test R^2 = 0.5500669633958264
#     Training VE_regdim = 0.23122910373200697
#     Test VE_regdim = 0.1877780388003694
#     Training VE_total = 3.1237540712271947
#     Test VE_total = 4.589205588319966
#
# Zara64 F5 movement onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.8269714002584345
#     Test R^2 = 0.56898555137603
#     Training VE_regdim = 0.23683262445591166
#     Test VE_regdim = 0.09577256857996475
#     Training VE_total = 4.690678602206147
#     Test VE_total = 3.0741541285589635
#
# Zara64 F5 hold onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.85686977664118
#     Test R^2 = 0.13781847104230488
#     Training VE_regdim = 0.21108130831234057
#     Test VE_regdim = 0.04823280797194953
#     Training VE_total = 3.238757799205531
#     Test VE_total = 4.806123716073223
#
# Zara64 F5 hold onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.8040663929902594
#     Test R^2 = 0.16709587644873894
#     Training VE_regdim = 0.24630501881432937
#     Test VE_regdim = 0.03577328812488827
#     Training VE_total = 4.9326260237734685
#     Test VE_total = 3.182612857270838
#
# Zara64 M1 go cue onset tested on active
#     Number of neurons = 99
#     Training R^2 = 0.313716242782817
#     Test R^2 = 0.2333933401075206
#     Training VE_regdim = 0.041355463636335625
#     Test VE_regdim = 0.0667398238350714
#     Training VE_total = 1.6199291287608617
#     Test VE_total = 3.83047704579014
#
# Zara64 M1 go cue onset tested on passive
#     Number of neurons = 99
#     Training R^2 = 0.6675190133606483
#     Test R^2 = 0.024922964642037738
#     Training VE_regdim = 0.1665501811013152
#     Test VE_regdim = 0.024610630662998224
#     Training VE_total = 3.9186355210038135
#     Test VE_total = 1.5604883310529318
#
# Zara64 M1 movement onset tested on active
#     Number of neurons = 99
#     Training R^2 = 0.4099568919601566
#     Test R^2 = 0.06414661283061737
#     Training VE_regdim = 0.04259787188693705
#     Test VE_regdim = 0.0417278003889192
#     Training VE_total = 1.730513976544269
#     Test VE_total = 4.29926767432274
#
# Zara64 M1 movement onset tested on passive
#     Number of neurons = 99
#     Training R^2 = 0.7955522845423075
#     Test R^2 = 0.027431076430342816
#     Training VE_regdim = 0.2021321307745791
#     Test VE_regdim = 0.031920898596137295
#     Training VE_total = 4.413067028457023
#     Test VE_total = 1.6677855244753286
#
# Zara64 M1 hold onset tested on active
#     Number of neurons = 99
#     Training R^2 = 0.632694264038365
#     Test R^2 = 0.10307217614362604
#     Training VE_regdim = 0.08703619614200889
#     Test VE_regdim = 0.09585097217661318
#     Training VE_total = 1.5813016648215894
#     Test VE_total = 4.221929506136894
#
# Zara64 M1 hold onset tested on passive
#     Number of neurons = 99
#     Training R^2 = 0.8244904210391428
#     Test R^2 = 0.0021562223232391544
#     Training VE_regdim = 0.2772380363064014
#     Test VE_regdim = 0.02459049270610554
#     Training VE_total = 4.3546414418732695
#     Test VE_total = 1.528073190299739
#
# Zara70 AIP go cue onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.5569110492917645
#     Test R^2 = 0.25037373289774034
#     Training VE_regdim = 0.19568458399463678
#     Test VE_regdim = 0.07269189150452568
#     Training VE_total = 3.5108687916923977
#     Test VE_total = 3.3324856269132246
#
# Zara70 AIP go cue onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.4083606022738163
#     Test R^2 = 0.40114506538828465
#     Training VE_regdim = 0.1437984262528189
#     Test VE_regdim = 0.08718698768709632
#     Training VE_total = 3.4131296630737404
#     Test VE_total = 3.466504984069514
#
# Zara70 AIP movement onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.688585899931535
#     Test R^2 = 0.4609463298305365
#     Training VE_regdim = 0.21100696045655226
#     Test VE_regdim = 0.0959334635145197
#     Training VE_total = 4.369775247270263
#     Test VE_total = 3.9232099840214447
#
# Zara70 AIP movement onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.6975531569210534
#     Test R^2 = 0.45806461082036076
#     Training VE_regdim = 0.20688375502649564
#     Test VE_regdim = 0.14446638458804725
#     Training VE_total = 4.004135704730571
#     Test VE_total = 4.327463905545899
#
# Zara70 AIP hold onset tested on active
#     Number of neurons = 121
#     Training R^2 = 0.677023326682033
#     Test R^2 = -0.15690994153725862
#     Training VE_regdim = 0.2792846189974054
#     Test VE_regdim = 0.05921793352085693
#     Training VE_total = 4.271290285163472
#     Test VE_total = 4.205335446417477
#
# Zara70 AIP hold onset tested on passive
#     Number of neurons = 121
#     Training R^2 = 0.5919546563484557
#     Test R^2 = -0.10366200894225672
#     Training VE_regdim = 0.1626221043891704
#     Test VE_regdim = 0.03016885960978579
#     Training VE_total = 4.287119437402234
#     Test VE_total = 4.2259306654883915
#
# Zara70 F5 go cue onset tested on active
#     Number of neurons = 108
#     Training R^2 = 0.5966392904961083
#     Test R^2 = 0.48657095169334375
#     Training VE_regdim = 0.14284194276548226
#     Test VE_regdim = 0.1571253838563787
#     Training VE_total = 2.7834058816113734
#     Test VE_total = 3.6243331114562842
#
# Zara70 F5 go cue onset tested on passive
#     Number of neurons = 108
#     Training R^2 = 0.5758506233727512
#     Test R^2 = 0.4037881046499988
#     Training VE_regdim = 0.2262484281825592
#     Test VE_regdim = 0.07746449681489338
#     Training VE_total = 3.730310363019091
#     Test VE_total = 2.731279055986749
#
# Zara70 F5 movement onset tested on active
#     Number of neurons = 108
#     Training R^2 = 0.7906563914154185
#     Test R^2 = 0.35403843680857355
#     Training VE_regdim = 0.1686657731302585
#     Test VE_regdim = 0.18450638201261577
#     Training VE_total = 3.004736048718925
#     Test VE_total = 4.428324351912207
#
# Zara70 F5 movement onset tested on passive
#     Number of neurons = 108
#     Training R^2 = 0.7559533534087961
#     Test R^2 = 0.40607265199122977
#     Training VE_regdim = 0.2262574166637849
#     Test VE_regdim = 0.0545626672502034
#     Training VE_total = 4.5568899084655135
#     Test VE_total = 2.951651388763488
#
# Zara70 F5 hold onset tested on active
#     Number of neurons = 108
#     Training R^2 = 0.7530389719984598
#     Test R^2 = 0.1898032686674493
#     Training VE_regdim = 0.130817541361088
#     Test VE_regdim = 0.04330915214893618
#     Training VE_total = 3.164745203886407
#     Test VE_total = 4.434542361974284
#
# Zara70 F5 hold onset tested on passive
#     Number of neurons = 108
#     Training R^2 = 0.7594854729879161
#     Test R^2 = 0.19490264457036105
#     Training VE_regdim = 0.2485643634311358
#     Test VE_regdim = 0.031377533258463854
#     Training VE_total = 4.568936982293666
#     Test VE_total = 3.101866986554258
#
# Zara70 M1 go cue onset tested on active
#     Number of neurons = 183
#     Training R^2 = 0.1630585256396955
#     Test R^2 = -0.049244481527468784
#     Training VE_regdim = 0.03850354170015195
#     Test VE_regdim = 0.05234564917010411
#     Training VE_total = 2.1691554724378053
#     Test VE_total = 6.108027600927019
#
# Zara70 M1 go cue onset tested on passive
#     Number of neurons = 183
#     Training R^2 = 0.5988916999335314
#     Test R^2 = -0.17272253485344305
#     Training VE_regdim = 0.14826446192802561
#     Test VE_regdim = 0.03949434282956556
#     Training VE_total = 6.24940286757845
#     Test VE_total = 2.1256106627483238
#
# Zara70 M1 movement onset tested on active
#     Number of neurons = 183
#     Training R^2 = 0.261244869899343
#     Test R^2 = -0.47957631235061376
#     Training VE_regdim = 0.042741588150529454
#     Test VE_regdim = 0.046392221404949516
#     Training VE_total = 2.293222616280385
#     Test VE_total = 8.98620165158789
#
# Zara70 M1 movement onset tested on passive
#     Number of neurons = 183
#     Training R^2 = 0.6844318081640879
#     Test R^2 = -0.14490471561768015
#     Training VE_regdim = 0.2920840809400507
#     Test VE_regdim = 0.03497433574937199
#     Training VE_total = 9.088004139595684
#     Test VE_total = 2.2474398547796044
#
# Zara70 M1 hold onset tested on active
#     Number of neurons = 183
#     Training R^2 = 0.45593641774767046
#     Test R^2 = -0.2541330675212467
#     Training VE_regdim = 0.05546083205268454
#     Test VE_regdim = 0.040189909638054945
#     Training VE_total = 2.3948145497562487
#     Test VE_total = 8.883885781725732
#
# Zara70 M1 hold onset tested on passive
#     Number of neurons = 183
#     Training R^2 = 0.8030832073945042
#     Test R^2 = -0.09550913793486412
#     Training VE_regdim = 0.41307732373876743
#     Test VE_regdim = 0.027503701434872685
#     Training VE_total = 9.011300537732824
#     Test VE_total = 2.3462718944461463
#
# Moe46 AIP go cue onset tested on active
#     Number of neurons = 102
#     Training R^2 = 0.2125332283734597
#     Test R^2 = 0.15637282360764482
#     Training VE_regdim = 0.06734727379965989
#     Test VE_regdim = 0.04959653140690138
#     Training VE_total = 2.9379593595919875
#     Test VE_total = 3.139869313049455
#
# Moe46 AIP go cue onset tested on passive
#     Number of neurons = 102
#     Training R^2 = 0.32796579962497546
#     Test R^2 = 0.09819166797176537
#     Training VE_regdim = 0.09435833975685685
#     Test VE_regdim = 0.040443017949316186
#     Training VE_total = 3.2727464815096794
#     Test VE_total = 2.8481262010860746
#
# Moe46 AIP movement onset tested on active
#     Number of neurons = 102
#     Training R^2 = 0.6729175409726527
#     Test R^2 = 0.5807226732519399
#     Training VE_regdim = 0.1796315865514261
#     Test VE_regdim = 0.12935316361709676
#     Training VE_total = 3.497911280088035
#     Test VE_total = 3.687559488313641
#
# Moe46 AIP movement onset tested on passive
#     Number of neurons = 102
#     Training R^2 = 0.6701966247448113
#     Test R^2 = 0.5787727195057865
#     Training VE_regdim = 0.18096935973543896
#     Test VE_regdim = 0.13625676537031348
#     Training VE_total = 3.847427862273327
#     Test VE_total = 3.394490716618724
#
# Moe46 AIP hold onset tested on active
#     Number of neurons = 102
#     Training R^2 = 0.6699928001267242
#     Test R^2 = 0.14652271739083716
#     Training VE_regdim = 0.14311913796339804
#     Test VE_regdim = 0.0508181456364061
#     Training VE_total = 3.7189788094710785
#     Test VE_total = 3.8416341877849867
#
# Moe46 AIP hold onset tested on passive
#     Number of neurons = 102
#     Training R^2 = 0.688875209080248
#     Test R^2 = 0.2825152399217175
#     Training VE_regdim = 0.15354191778668275
#     Test VE_regdim = 0.03785960415854457
#     Training VE_total = 3.9882932642700752
#     Test VE_total = 3.637940981411748
#
# Moe46 F5 go cue onset tested on active
#     Number of neurons = 191
#     Training R^2 = 0.3802274845491566
#     Test R^2 = 0.3502055340662185
#     Training VE_regdim = 0.11261470776722189
#     Test VE_regdim = 0.0772952900799952
#     Training VE_total = 4.749539302814581
#     Test VE_total = 5.9134903439769015
#
# Moe46 F5 go cue onset tested on passive
#     Number of neurons = 191
#     Training R^2 = 0.4542097426491033
#     Test R^2 = 0.21198632369540524
#     Training VE_regdim = 0.18855598567535242
#     Test VE_regdim = 0.07754616995370026
#     Training VE_total = 6.25535626555412
#     Test VE_total = 4.667468027340044
#
# Moe46 F5 movement onset tested on active
#     Number of neurons = 191
#     Training R^2 = 0.7154330149020914
#     Test R^2 = 0.46797396142713
#     Training VE_regdim = 0.1795225073523284
#     Test VE_regdim = 0.09352559579046071
#     Training VE_total = 4.957145330407256
#     Test VE_total = 7.999196799486954
#
# Moe46 F5 movement onset tested on passive
#     Number of neurons = 191
#     Training R^2 = 0.8050409567517278
#     Test R^2 = 0.2596878883845165
#     Training VE_regdim = 0.3473774194070492
#     Test VE_regdim = 0.0696926761501179
#     Training VE_total = 8.36911779376757
#     Test VE_total = 4.888227876529704
#
# Moe46 F5 hold onset tested on active
#     Number of neurons = 191
#     Training R^2 = 0.7554171218855225
#     Test R^2 = 0.4067160647918239
#     Training VE_regdim = 0.20410444299252134
#     Test VE_regdim = 0.08059624882708231
#     Training VE_total = 5.0921772251716035
#     Test VE_total = 8.540614300381161
#
# Moe46 F5 hold onset tested on passive
#     Number of neurons = 191
#     Training R^2 = 0.8193420450517263
#     Test R^2 = 0.31732478443463225
#     Training VE_regdim = 0.348195122124796
#     Test VE_regdim = 0.05951893092608064
#     Training VE_total = 8.910310642778624
#     Test VE_total = 5.037695745434431
#
# Moe46 M1 go cue onset tested on active
#     Number of neurons = 149
#     Training R^2 = 0.23331699491142316
#     Test R^2 = 0.08540275148846035
#     Training VE_regdim = 0.057472499651122576
#     Test VE_regdim = 0.05579821504122377
#     Training VE_total = 2.8081548180013556
#     Test VE_total = 4.360008276628828
#
# Moe46 M1 go cue onset tested on passive
#     Number of neurons = 149
#     Training R^2 = 0.41025534277711095
#     Test R^2 = -0.024878383534687475
#     Training VE_regdim = 0.18324310997901494
#     Test VE_regdim = 0.03251668511181662
#     Training VE_total = 4.496631212277445
#     Test VE_total = 2.718938453495293
#
# Moe46 M1 movement onset tested on active
#     Number of neurons = 149
#     Training R^2 = 0.5542614539589807
#     Test R^2 = 0.12489873533380139
#     Training VE_regdim = 0.07956368326680255
#     Test VE_regdim = 0.09120731654586943
#     Training VE_total = 2.986257490542474
#     Test VE_total = 6.111278872856681
#
# Moe46 M1 movement onset tested on passive
#     Number of neurons = 149
#     Training R^2 = 0.7082155686865526
#     Test R^2 = 0.13800821172563354
#     Training VE_regdim = 0.22303026827801245
#     Test VE_regdim = 0.025960185043664784
#     Training VE_total = 6.245334496141653
#     Test VE_total = 2.899674627021839
#
# Moe46 M1 hold onset tested on active
#     Number of neurons = 149
#     Training R^2 = 0.46073538455987606
#     Test R^2 = -0.12674167976072087
#     Training VE_regdim = 0.08643780394126792
#     Test VE_regdim = 0.053296088738227554
#     Training VE_total = 2.8283347051571894
#     Test VE_total = 6.326214732929073
#
# Moe46 M1 hold onset tested on passive
#     Number of neurons = 149
#     Training R^2 = 0.825496591163196
#     Test R^2 = -0.01904675210014086
#     Training VE_regdim = 0.3146639207111717
#     Test VE_regdim = 0.01636403661447762
#     Training VE_total = 6.479031022601156
#     Test VE_total = 2.7619250701847022
# Moe50 AIP go cue onset tested on active
#     Number of neurons = 67
#     Training R^2 = 0.29608819619969884
#     Test R^2 = 0.3290058446076277
#     Training VE_regdim = 0.0466228517560139
#     Test VE_regdim = 0.03798973390408576
#     Training VE_total = 1.5353271023464266
#     Test VE_total = 1.9039161286997743
#
# Moe50 AIP go cue onset tested on passive
#     Number of neurons = 67
#     Training R^2 = 0.4525993026538543
#     Test R^2 = 0.11175088197779814
#     Training VE_regdim = 0.08112539890583916
#     Test VE_regdim = 0.04052162510937476
#     Training VE_total = 1.9731834307125387
#     Test VE_total = 1.4803170340909164
#
# Moe50 AIP movement onset tested on active
#     Number of neurons = 67
#     Training R^2 = 0.6847540737127753
#     Test R^2 = 0.610283089090655
#     Training VE_regdim = 0.18064126899436134
#     Test VE_regdim = 0.13789336378731382
#     Training VE_total = 2.079261495482198
#     Test VE_total = 2.475538137897818
#
# Moe50 AIP movement onset tested on passive
#     Number of neurons = 67
#     Training R^2 = 0.7621275278098228
#     Test R^2 = 0.5834334789044129
#     Training VE_regdim = 0.17461693589102661
#     Test VE_regdim = 0.16093024613863022
#     Training VE_total = 2.5688663664419686
#     Test VE_total = 1.9985756646911743
#
# Moe50 AIP hold onset tested on active
#     Number of neurons = 67
#     Training R^2 = 0.5416290966503319
#     Test R^2 = 0.0034956907339276587
#     Training VE_regdim = 0.10873004921259102
#     Test VE_regdim = 0.04914840721309351
#     Training VE_total = 2.472700210596111
#     Test VE_total = 2.659538689069534
#
# Moe50 AIP hold onset tested on passive
#     Number of neurons = 67
#     Training R^2 = 0.5853525516834042
#     Test R^2 = -0.0334380740529437
#     Training VE_regdim = 0.12118814718298784
#     Test VE_regdim = 0.03628549499293966
#     Training VE_total = 2.763788178879677
#     Test VE_total = 2.374493337829075
#
# Moe50 F5 go cue onset tested on active
#     Number of neurons = 206
#     Training R^2 = 0.5539811058687818
#     Test R^2 = 0.5299250359251859
#     Training VE_regdim = 0.17636271689589694
#     Test VE_regdim = 0.14198359281216344
#     Training VE_total = 6.938674862941674
#     Test VE_total = 8.433299041767505
#
# Moe50 F5 go cue onset tested on passive
#     Number of neurons = 206
#     Training R^2 = 0.6269647383956811
#     Test R^2 = 0.3312534001746952
#     Training VE_regdim = 0.3178674491918186
#     Test VE_regdim = 0.10806595981688727
#     Training VE_total = 8.522931755498634
#     Test VE_total = 6.847068223057538
#
# Moe50 F5 movement onset tested on active
#     Number of neurons = 206
#     Training R^2 = 0.7694098933425655
#     Test R^2 = 0.6096306687310475
#     Training VE_regdim = 0.29900773911231443
#     Test VE_regdim = 0.21147260570536974
#     Training VE_total = 7.6716678761238155
#     Test VE_total = 10.280149727556068
#
# Moe50 F5 movement onset tested on passive
#     Number of neurons = 206
#     Training R^2 = 0.8689798742725703
#     Test R^2 = 0.5709400167422484
#     Training VE_regdim = 0.46166513832550243
#     Test VE_regdim = 0.15975014702663795
#     Training VE_total = 10.382200164002398
#     Test VE_total = 7.592925267757403
#
# Moe50 F5 hold onset tested on active
#     Number of neurons = 206
#     Training R^2 = 0.7855988684776928
#     Test R^2 = 0.4707225557416749
#     Training VE_regdim = 0.32157290442492503
#     Test VE_regdim = 0.1472448581946558
#     Training VE_total = 8.379593356465605
#     Test VE_total = 10.901908017881814
#
# Moe50 F5 hold onset tested on passive
#     Number of neurons = 206
#     Training R^2 = 0.8653920976402809
#     Test R^2 = 0.4741627143156276
#     Training VE_regdim = 0.5657557184083895
#     Test VE_regdim = 0.16626986415410794
#     Training VE_total = 11.013178588335238
#     Test VE_total = 8.301354056377141
#
# Moe50 M1 go cue onset tested on active
#     Number of neurons = 164
#     Training R^2 = 0.36015311559596197
#     Test R^2 = -0.08083653885603796
#     Training VE_regdim = 0.06373323954427362
#     Test VE_regdim = 0.04035221283157851
#     Training VE_total = 3.0612808366581703
#     Test VE_total = 5.867107589244541
#
# Moe50 M1 go cue onset tested on passive
#     Number of neurons = 164
#     Training R^2 = 0.6013558524457998
#     Test R^2 = 0.002515180510022286
#     Training VE_regdim = 0.19833176645162515
#     Test VE_regdim = 0.03782018796056937
#     Training VE_total = 5.990692412681938
#     Test VE_total = 2.9701814879552386
#
# Moe50 M1 movement onset tested on active
#     Number of neurons = 164
#     Training R^2 = 0.7638477996028954
#     Test R^2 = 0.38688321007905613
#     Training VE_regdim = 0.18247202900135723
#     Test VE_regdim = 0.10395059240117115
#     Training VE_total = 3.4365730183356726
#     Test VE_total = 7.412551354111254
#
# Moe50 M1 movement onset tested on passive
#     Number of neurons = 164
#     Training R^2 = 0.772939165316154
#     Test R^2 = 0.387714566585525
#     Training VE_regdim = 0.21551850804165382
#     Test VE_regdim = 0.06072287160672093
#     Training VE_total = 7.561850129074625
#     Test VE_total = 3.347489901447452
#
# Moe50 M1 hold onset tested on active
#     Number of neurons = 164
#     Training R^2 = 0.6880218802076167
#     Test R^2 = 0.07210099247603866
#     Training VE_regdim = 0.10168616110007841
#     Test VE_regdim = 0.12955070200020138
#     Training VE_total = 3.600106399072561
#     Test VE_total = 7.5532247598208215
#
# Moe50 M1 hold onset tested on passive
#     Number of neurons = 164
#     Training R^2 = 0.7942634716923553
#     Test R^2 = 0.13877505275316226
#     Training VE_regdim = 0.31233327039270364
#     Test VE_regdim = 0.02589432303395975
#     Training VE_total = 7.705888195922961
#     Test VE_total = 3.499943078131973

# %%
# prep the data for plotting

# get the data ready for plotting
# x = before
# y = after

rg=np.random.default_rng()

y       = []
yhat    = []
trainR2 = []
testR2  = []
trainVE_regdim = []
testVE_regdim  = []
trainVE_total  = []
testVE_total   = []
session_ = []
area_    = []
align_   = []
testcontext_ = []

for session in timedecs:
    for area in timedecs[session]:
        for align in timedecs[session][area]:
            for testcontext in timedecs[session][area][align]:
                temp = timedecs[session][area][align][testcontext]
                len_ = len(temp['y'])
                
                # randomly sample 1% of these points because this is ridiculous
                keepinds = list( rg.choice(len_,int(len_/100)) )
                
                # reset len
                len_     = len(keepinds)
                
                
                # don't worry too much about within-run variances, SEMs, or such. We're pooling & doing SEMs based on that                
                y       += [temp['y'][idx] for idx in keepinds]
                yhat    += [temp['yhat'][idx] for idx in keepinds]
                trainR2 += [np.mean(temp['trainR2']) for _ in range(len_)]
                testR2  += [np.mean(temp['testR2']) for _ in range(len_)]
                trainVE_regdim += [np.mean(temp['trainVE_regdim']) for _ in range(len_)]
                testVE_regdim  += [np.mean(temp['testVE_regdim']) for _ in range(len_)]
                trainVE_total  += [np.mean(temp['trainVE_total']) for _ in range(len_)]
                testVE_total   += [np.mean(temp['testVE_total']) for _ in range(len_)]
                session_ += [session for _ in range(len_)]
                area_    += [area for _ in range(len_)]
                align_   += [align for _ in range(len_)]
                testcontext_ += [testcontext for _ in range(len_)]
        
dd = {'y':y,
      'yhat':yhat,
      'trainR2':trainR2,
      'testR2':testR2,
      'trainVE_regdim':trainVE_regdim,
      'testVE_regdim':testVE_regdim,
      'trainVE_total':trainVE_total,
      'testVE_total':testVE_total,
      'session':session_,
      'area':area_,
      'align':align_,
      'testcontext':testcontext_}

df = pd.DataFrame(dd)
fname = os.path.join('pythonfigures','timeregression.json')
df.to_json(fname) # to sql was probably better...

print(df)
# Out:
#          y        yhat   trainR2    testR2  trainVE_regdim  testVE_regdim  \
# 0       65 -123.498529  0.582165  0.462540        0.235854       0.121769
# 1     -125 -192.437896  0.582165  0.462540        0.235854       0.121769
# 2     -435 -108.412626  0.582165  0.462540        0.235854       0.121769
# 3      -75  -96.027704  0.582165  0.462540        0.235854       0.121769
# 4     -385 -196.575198  0.582165  0.462540        0.235854       0.121769
# ...    ...         ...       ...       ...             ...            ...
# 19048 -135   96.168494  0.794263  0.138775        0.312333       0.025894
# 19049  265   36.680698  0.794263  0.138775        0.312333       0.025894
# 19050  345   10.785184  0.794263  0.138775        0.312333       0.025894
# 19051 -265 -103.704709  0.794263  0.138775        0.312333       0.025894
# 19052 -185  -44.986573  0.794263  0.138775        0.312333       0.025894
#
#        trainVE_total  testVE_total session area         align   testcontext
# 0           3.473826      3.101237  Zara64  AIP  go cue onset   active_test
# 1           3.473826      3.101237  Zara64  AIP  go cue onset   active_test
# 2           3.473826      3.101237  Zara64  AIP  go cue onset   active_test
# 3           3.473826      3.101237  Zara64  AIP  go cue onset   active_test
# 4           3.473826      3.101237  Zara64  AIP  go cue onset   active_test
# ...              ...           ...     ...  ...           ...           ...
# 19048       7.705888      3.499943   Moe50   M1    hold onset  passive_test
# 19049       7.705888      3.499943   Moe50   M1    hold onset  passive_test
# 19050       7.705888      3.499943   Moe50   M1    hold onset  passive_test
# 19051       7.705888      3.499943   Moe50   M1    hold onset  passive_test
# 19052       7.705888      3.499943   Moe50   M1    hold onset  passive_test
#
# [19053 rows x 12 columns]

# %%
fname  = os.path.join('pythonfigures','timeregression.json')
df     = pd.read_json(fname)
colors = pd.read_csv(os.path.join('pythonfigures','colors.csv'))

# first off, make a scatterplot for each area x align x test context
for area in pd.unique(df['area']):
    # movement onset is clearly the best-performing alignment, so just roll with that
    for align in ['movement onset']: #pd.unique(df['align']):
        # just pool test contexts
        c = colors[colors['Area']==area].to_numpy()
        c = c[0][:3]
        scatterdf = df[['y','yhat','testR2']][(df['area']==area) & (df['align']==align)]

        fig = go.Figure()
        fig.add_trace(
            go.Scatter(
                x=scatterdf['y'], 
                y=scatterdf['yhat'], 
                mode='markers', 
                marker=dict(
                    color=f'rgba({c[0]},{c[1]},{c[2]},0.2)', 
                    size=5), 
                showlegend=False)
        )
        fig.update_layout(
            title=dict(
                text=f"{area}: R\u00B2={scatterdf['testR2'].mean():.2f}",
                xanchor='left'
            ),
            xaxis_title=f'Time from {align} (ms)', 
            yaxis_title=f'Estimated time from {align} (ms)', 
            xaxis_showgrid=False, 
            yaxis_showgrid=False, 
            plot_bgcolor='rgba(0,0,0,0)',
            xaxis_range=[-550, 550], 
            yaxis_range=[-900, 900],
            width=550/2,
            height=900/2
        )
        fig.update_xaxes(ticks='outside',
                                   tickwidth=1,
                                   tickcolor='black',
                                   ticklen=4,
                                   linecolor='rgba(0,0,0,1)',
                                   linewidth=1,
                                   showgrid=False)

        fig.update_yaxes(ticks='outside',
                                       tickwidth=1,
                                       tickcolor='black',
                                       ticklen=4,
                                       linecolor='rgba(0,0,0,1)',
                                       linewidth=1,
                                       showgrid=False
                                       )
        fig.add_shape(type='line', 
                      x0=-550, 
                      y0=-550, 
                      x1=550, 
                      y1=550, 
                      line=dict(
                          color='black', 
                          width=2)
        )
        fig.show(renderer="svg")
        fig.write_image(os.path.join('figs',f'{area}_timeregress.svg'))

# %% [markdown]
# # Grip decoding time (with subsampling!)

# %%
# now, self-classification
subsampaccs = dict()
rg=np.random.default_rng()

for session in sessions:
    subsampaccs[session] = dict()
    
    for area in areas:
        subsampaccs[session][area] = dict()
        
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','object','grip','turntable','alignment'])
        
        df = dp.readQuery(0)
        df['turntable'] = df['turntable'] // 10
        
        cnames = dp.get('neuronColumnNames')
        
        # subsamples
        for subsampsize in [6,60]:
            subsampaccs[session][area][subsampsize] = list()
            for subsampiter in range(10):
                temp = dict()
                colinds = rg.choice(len(cnames),subsampsize)
                csamp   = [cnames[idx] for idx in colinds]
            
                # no need to account for object vision yet. we worry about that at the subspace alignment phase, but it doesn't affect classification all that much!
                df_movement_trials = df[(df['alignment']=='hold onset') & (df['time']<0)].groupby(['context','turntable','grip','trial'],sort=False)[csamp].aggregate('mean')

                # okay, let's iterate through contexts
                for context in ['active','passive']:
                    print(f"{session} {area} {context} {subsampsize}")
                    temp[context] = dict()

                    # extract the context (and ignore the special turntable to get your chance level under control... but DO leave it in when estimating the subspace spanned by the object vision repertoire)
                    df_movement_context  = df_movement_trials.loc[(df_movement_trials.index.get_level_values(0)==context) & (df_movement_trials.index.get_level_values(1)!=9)] # keep the context multiindex level here, too
                    labels = df_movement_context.index.get_level_values(2)

                    axesToRemove  = 0
                    neurcount     = len(dp.get('neuronColumnNames'))
                    pccount       = min(30,subsampsize)
                    nsplits       = 5

                    skf     = StratifiedKFold(n_splits=nsplits,shuffle=False)
                    splits  = skf.split(np.zeros(len(labels)),labels)
                    splits  = list(splits) # store as list to allow it to be used many of time

                    # step 2: cross-validated model fitting & evaluation
                    correct_count = 0
                    chance_count  = 0
                    total_count   = len(labels)

                    for fold,(train_,test_) in enumerate(splits):
                        trainX = df_movement_context.iloc[train_].to_numpy()
                        trainy = labels[train_].to_numpy()

                        testX  = df_movement_context.iloc[test_].to_numpy()
                        testy  = labels[test_].to_numpy()

                        # now fit a PC model in the remaining space to make sure LDA input is well-conditioned (this improves cross-validated performance)
                        PCmdl = PCA(n_components=pccount)
                        trainX = PCmdl.fit_transform(trainX)
                        testX  = PCmdl.transform(testX)

                        # now we can finally start classifying!
                        LDmdl = LDA()
                        LDmdl.fit(trainX,trainy)
                        yhat = LDmdl.predict(testX)

                        correct_count += np.sum(yhat==testy)
                        chance_count  += len(testy) * max(LDmdl.priors_)

                    correct_rate   = correct_count / total_count
                    chance_rate    = chance_count / total_count
                    threshold_rate = chance_rate + np.sqrt( chance_rate*(1-chance_rate)/total_count ) # chance + 1 SE

                    temp[context]['correct_count'] = correct_count
                    temp[context]['chance_count']  = chance_count
                    temp[context]['total_count']   = total_count
                    temp[context]['total_neuron_count']  = len(dp.get('neuronColumnNames'))

                    print(f"    Total number of neurons = {len(dp.get('neuronColumnNames'))}")
                    print(f"    Sumbsample size = {subsampsize}")
                    print(f"    Accuracy = {correct_rate}")
                    print(f"    Chance = {chance_rate}")
                    print(f"    Threshold = {threshold_rate}")
                    print()
                # for context in ['active','passive']
                subsampaccs[session][area][subsampsize] += [temp]
            # for subsampiter in range(10)
# Out:
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.21468926553672316
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.25280898876404495
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2994350282485876
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.14606741573033707
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3502824858757062
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.29775280898876405
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.6101694915254238
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3595505617977528
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.23728813559322035
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.25842696629213485
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.22598870056497175
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.1404494382022472
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.4632768361581921
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2752808988764045
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2598870056497175
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.1853932584269663
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2033898305084746
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.1404494382022472
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3559322033898305
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.16853932584269662
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.576271186440678
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3146067415730337
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6101694915254238
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.2640449438202247
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.672316384180791
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.398876404494382
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5254237288135594
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.2696629213483146
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.4632768361581921
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.2303370786516854
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6949152542372882
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.4101123595505618
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.4745762711864407
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.33707865168539325
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6610169491525424
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3146067415730337
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5536723163841808
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3146067415730337
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.384180790960452
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.2247191011235955
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.4519774011299435
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2247191011235955
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3559322033898305
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.25280898876404495
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3559322033898305
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2303370786516854
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3502824858757062
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.17415730337078653
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3502824858757062
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.14606741573033707
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2655367231638418
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.19101123595505617
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2598870056497175
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.24719101123595505
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2994350282485876
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.15730337078651685
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.559322033898305
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.0898876404494382
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.1977401129943503
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.1853932584269663
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.7005649717514124
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.33707865168539325
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6045197740112994
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.29775280898876405
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.7005649717514124
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3202247191011236
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6101694915254238
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3595505617977528
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6045197740112994
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3258426966292135
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5819209039548022
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.33707865168539325
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5084745762711864
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3595505617977528
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5706214689265536
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3146067415730337
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6610169491525424
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.2752808988764045
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 F5 active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5706214689265536
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 F5 passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3146067415730337
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.3954802259887006
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.1797752808988764
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.3107344632768362
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.17415730337078653
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.4124293785310734
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.15730337078651685
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.327683615819209
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.12921348314606743
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.3728813559322034
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.23595505617977527
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.24858757062146894
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.16292134831460675
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.4011299435028249
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.16853932584269662
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.3389830508474576
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.20786516853932585
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.4011299435028249
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.12921348314606743
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.4067796610169492
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 6
#     Total number of neurons = 99
#     Sumbsample size = 6
#     Accuracy = 0.1348314606741573
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.576271186440678
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.17415730337078653
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.6045197740112994
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.20224719101123595
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.672316384180791
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.2640449438202247
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.4632768361581921
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.2247191011235955
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.5875706214689266
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.21348314606741572
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.7005649717514124
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.20786516853932585
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.6214689265536724
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.20224719101123595
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.5649717514124294
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.24157303370786518
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.4745762711864407
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.24719101123595505
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara64 M1 active 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.672316384180791
#     Chance = 0.22033221083926324
#     Threshold = 0.2514857333437951
#
# Zara64 M1 passive 60
#     Total number of neurons = 99
#     Sumbsample size = 60
#     Accuracy = 0.21910112359550563
#     Chance = 0.1685492858146759
#     Threshold = 0.19660825502560722
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.21610169491525424
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.12184873949579832
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3177966101694915
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.33613445378151263
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.24152542372881355
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.12605042016806722
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3686440677966102
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.18907563025210083
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2838983050847458
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.18907563025210083
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3474576271186441
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.22268907563025211
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2542372881355932
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.20588235294117646
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2923728813559322
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.22268907563025211
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.3601694915254237
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.14285714285714285
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.2669491525423729
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 6
#     Total number of neurons = 121
#     Sumbsample size = 6
#     Accuracy = 0.226890756302521
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.4872881355932203
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.24369747899159663
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.538135593220339
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.35714285714285715
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.4915254237288136
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.18907563025210083
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.6271186440677966
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3487394957983193
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5805084745762712
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3067226890756303
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5889830508474576
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.29831932773109243
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.18487394957983194
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.614406779661017
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.35714285714285715
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.538135593220339
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.33613445378151263
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 AIP active 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.5932203389830508
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 AIP passive 60
#     Total number of neurons = 121
#     Sumbsample size = 60
#     Accuracy = 0.3025210084033613
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.1483050847457627
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.09663865546218488
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.3093220338983051
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.18907563025210083
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.3050847457627119
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.1638655462184874
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.2796610169491525
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.12605042016806722
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.2669491525423729
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.15546218487394958
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.3432203389830508
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.20168067226890757
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.2711864406779661
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.15966386554621848
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.3644067796610169
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.18067226890756302
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.3559322033898305
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.19327731092436976
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.1906779661016949
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 6
#     Total number of neurons = 108
#     Sumbsample size = 6
#     Accuracy = 0.1722689075630252
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.5084745762711864
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.25210084033613445
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.5423728813559322
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.25630252100840334
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.5423728813559322
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.20588235294117646
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.5127118644067796
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.23949579831932774
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.4915254237288136
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.15966386554621848
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.5932203389830508
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.29831932773109243
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.4406779661016949
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.23109243697478993
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.4788135593220339
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.21008403361344538
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.4491525423728814
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.19747899159663865
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 F5 active 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.4915254237288136
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 F5 passive 60
#     Total number of neurons = 108
#     Sumbsample size = 60
#     Accuracy = 0.25630252100840334
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.23728813559322035
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.12605042016806722
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.2754237288135593
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.10504201680672269
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.23728813559322035
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.10504201680672269
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.2330508474576271
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.13865546218487396
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.2754237288135593
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.10504201680672269
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.2245762711864407
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.07563025210084033
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.2923728813559322
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.10084033613445378
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.3135593220338983
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.14705882352941177
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.1906779661016949
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.09663865546218488
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.17796610169491525
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 6
#     Total number of neurons = 183
#     Sumbsample size = 6
#     Accuracy = 0.1092436974789916
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4788135593220339
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.13025210084033614
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4491525423728814
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.10084033613445378
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4449152542372881
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.11764705882352941
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4194915254237288
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.11764705882352941
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4449152542372881
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.15126050420168066
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.5084745762711864
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.12184873949579832
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.3813559322033898
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.09243697478991597
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4025423728813559
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.07142857142857142
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.5084745762711864
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.15126050420168066
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Zara70 M1 active 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.4957627118644068
#     Chance = 0.1694953415112088
#     Threshold = 0.19391805519574803
#
# Zara70 M1 passive 60
#     Total number of neurons = 183
#     Sumbsample size = 60
#     Accuracy = 0.1638655462184874
#     Chance = 0.12605458827234392
#     Threshold = 0.1475691747888004
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.37272727272727274
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.19230769230769232
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.509090909090909
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.27564102564102566
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.38181818181818183
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.3525641025641026
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.2863636363636364
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.23076923076923078
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.33181818181818185
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.23076923076923078
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.2545454545454545
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.26282051282051283
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.2909090909090909
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.17307692307692307
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.3090909090909091
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.19230769230769232
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.2863636363636364
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.21794871794871795
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.16818181818181818
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 6
#     Total number of neurons = 102
#     Sumbsample size = 6
#     Accuracy = 0.1794871794871795
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 60
#     Total number of neurons = 102
#     Sumbsample size = 60
#     Accuracy = 0.6954545454545454
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 60
#     Total number of neurons = 102
#     Sumbsample size = 60
#     Accuracy = 0.47435897435897434
#     Chance = 0.23079404466501238
#     Threshold = 0.2645283148467347
#
# Moe46 AIP active 60
#     Total number of neurons = 102
#     Sumbsample size = 60
#     Accuracy = 0.6681818181818182
#     Chance = 0.22272727272727272
#     Threshold = 0.25077915928761463
#
# Moe46 AIP passive 60
#     Total number of neurons = 102
#     Sumbsample size = 60
#     Accuracy = 0.4230769230769231
#     Chance = 0.23079404466501238
# ...
#
# Moe50 AIP active 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.6807511737089202
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 AIP passive 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.5446009389671361
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 AIP active 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.755868544600939
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 AIP passive 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.5915492957746479
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 AIP active 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.7417840375586855
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 AIP passive 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.5305164319248826
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 AIP active 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.7370892018779343
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 AIP passive 60
#     Total number of neurons = 67
#     Sumbsample size = 60
#     Accuracy = 0.4835680751173709
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.38028169014084506
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.14553990610328638
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.3474178403755869
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.11267605633802817
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.2347417840375587
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.1643192488262911
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.48826291079812206
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.18309859154929578
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.5727699530516432
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.1643192488262911
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.3004694835680751
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.13615023474178403
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.323943661971831
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.18779342723004694
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.28169014084507044
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.14553990610328638
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.2863849765258216
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.09859154929577464
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.26291079812206575
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 6
#     Total number of neurons = 206
#     Sumbsample size = 6
#     Accuracy = 0.17370892018779344
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.7464788732394366
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.18309859154929578
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.704225352112676
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.24413145539906103
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.7323943661971831
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.27699530516431925
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.6901408450704225
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.2535211267605634
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.6291079812206573
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.2112676056338028
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.7793427230046949
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.2112676056338028
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.7605633802816901
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.1784037558685446
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.704225352112676
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.20657276995305165
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.7511737089201878
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.3004694835680751
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 F5 active 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.7652582159624414
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 F5 passive 60
#     Total number of neurons = 206
#     Sumbsample size = 60
#     Accuracy = 0.2112676056338028
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.24882629107981222
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.14553990610328638
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.3145539906103286
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.11267605633802817
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.3286384976525822
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.1596244131455399
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.2676056338028169
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.107981220657277
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.5915492957746479
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.16901408450704225
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.4413145539906103
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.215962441314554
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.3755868544600939
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.13145539906103287
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.2535211267605634
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.18309859154929578
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.22535211267605634
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.1596244131455399
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.3004694835680751
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 6
#     Total number of neurons = 164
#     Sumbsample size = 6
#     Accuracy = 0.17370892018779344
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.568075117370892
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.19248826291079812
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.5539906103286385
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.1643192488262911
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.5539906103286385
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.1596244131455399
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.676056338028169
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.14553990610328638
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.7276995305164319
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.22535211267605634
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.676056338028169
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.215962441314554
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.5821596244131455
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.2112676056338028
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.5117370892018779
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.24413145539906103
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.6150234741784038
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.22535211267605634
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245
#
# Moe50 M1 active 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.7370892018779343
#     Chance = 0.22538893491668965
#     Threshold = 0.25401873676161796
#
# Moe50 M1 passive 60
#     Total number of neurons = 164
#     Sumbsample size = 60
#     Accuracy = 0.20657276995305165
#     Chance = 0.16432603187061826
#     Threshold = 0.18971714960339245

# %%
# prep the data for plotting

# get the data ready for plotting
# active-6 | active-60 | passive-6 | passive-60
# for each area

acc_ = []
chance_ = []
session_ = []
animal_ = []
area_ = []
context_ = []
neuroncount_ = []

for session in subsampaccs:
    for area in subsampaccs[session]:
        for subsampsize in subsampaccs[session][area]:
            for subsampiter in subsampaccs[session][area][subsampsize]:
                for context in subsampiter:
                    temp      = subsampiter[context]
                    acc_     += [temp['correct_count'] / temp['total_count']]
                    chance_  += [temp['chance_count'] / temp['total_count']]
                    session_ += [session]
                    
                    an,_ = mysplit(session)
                    animal_  += [an]
                    
                    area_    += [area]
                    context_ += [context]
                    neuroncount_ += [subsampsize]
        
dd = {'acc':acc_,
      'chance':chance_,
      'session':session_,
      'animal':animal_,
      'area':area_,
      'context':context_,
      'neuroncount':neuroncount_}

df = pd.DataFrame(dd)

print(df)

fname = os.path.join('pythonfigures','subsampclassify.json')
df.to_json(fname) # to sql was probably better...

mu = df.groupby(['area','context','neuroncount'])[['acc','chance']].mean()
se = df.groupby(['area','context','neuroncount'])[['acc']].sem()
print(mu)
print(se)
# Out:
#           acc    chance session animal area  context  neuroncount
# 0    0.214689  0.220332  Zara64   Zara  AIP   active            6
# 1    0.252809  0.168549  Zara64   Zara  AIP  passive            6
# 2    0.299435  0.220332  Zara64   Zara  AIP   active            6
# 3    0.146067  0.168549  Zara64   Zara  AIP  passive            6
# 4    0.350282  0.220332  Zara64   Zara  AIP   active            6
# ..        ...       ...     ...    ...  ...      ...          ...
# 475  0.244131  0.164326   Moe50    Moe   M1  passive           60
# 476  0.615023  0.225389   Moe50    Moe   M1   active           60
# 477  0.225352  0.164326   Moe50    Moe   M1  passive           60
# 478  0.737089  0.225389   Moe50    Moe   M1   active           60
# 479  0.206573  0.164326   Moe50    Moe   M1  passive           60
#
# [480 rows x 7 columns]
#                                acc    chance
# area context neuroncount
# AIP  active  6            0.314526  0.209486
#              60           0.634286  0.209486
#      passive 6            0.207256  0.172431
#              60           0.385898  0.172431
# F5   active  6            0.327635  0.209486
#              60           0.646464  0.209486
#      passive 6            0.179918  0.172431
#              60           0.266466  0.172431
# M1   active  6            0.318476  0.209486
#              60           0.578091  0.209486
#      passive 6            0.158372  0.172431
#              60           0.210944  0.172431
#                                acc
# area context neuroncount
# AIP  active  6            0.014412
#              60           0.015803
#      passive 6            0.009962
#              60           0.017216
# F5   active  6            0.015963
#              60           0.017058
#      passive 6            0.006987
#              60           0.010243
# M1   active  6            0.014763
#              60           0.015171
#      passive 6            0.007619
#              60           0.011821

# %%
print(mu)

mu_area = mu.loc['AIP',:,:]

print(mu_area)

mu_list = mu_area['acc'].loc[:,60].to_list()

print(mu_list)
# Out:
#                                acc    chance
# area context neuroncount
# AIP  active  6            0.314526  0.209486
#              60           0.634286  0.209486
#      passive 6            0.207256  0.172431
#              60           0.385898  0.172431
# F5   active  6            0.327635  0.209486
#              60           0.646464  0.209486
#      passive 6            0.179918  0.172431
#              60           0.266466  0.172431
# M1   active  6            0.318476  0.209486
#              60           0.578091  0.209486
#      passive 6            0.158372  0.172431
#              60           0.210944  0.172431
#                           acc    chance
# context neuroncount
# active  6            0.314526  0.209486
#         60           0.634286  0.209486
# passive 6            0.207256  0.172431
#         60           0.385898  0.172431
# [0.6342857013679406, 0.3858984863559652]

# %%
print(df)
# Out:
#           acc    chance session animal area  context  neuroncount
# 0    0.214689  0.220332  Zara64   Zara  AIP   active            6
# 1    0.252809  0.168549  Zara64   Zara  AIP  passive            6
# 2    0.299435  0.220332  Zara64   Zara  AIP   active            6
# 3    0.146067  0.168549  Zara64   Zara  AIP  passive            6
# 4    0.350282  0.220332  Zara64   Zara  AIP   active            6
# ..        ...       ...     ...    ...  ...      ...          ...
# 475  0.244131  0.164326   Moe50    Moe   M1  passive           60
# 476  0.615023  0.225389   Moe50    Moe   M1   active           60
# 477  0.225352  0.164326   Moe50    Moe   M1  passive           60
# 478  0.737089  0.225389   Moe50    Moe   M1   active           60
# 479  0.206573  0.164326   Moe50    Moe   M1  passive           60
#
# [480 rows x 7 columns]

# %%
# bar plots!
fname   = os.path.join('pythonfigures','subsampclassify.json')
df      = pd.read_json(fname)
colors_ = pd.read_csv(os.path.join('pythonfigures','colors.csv'))

mu_ = df.groupby(['area','context','neuroncount'])[['acc','chance']].mean()
se_ = df.groupby(['area','context','neuroncount'])[['acc']].sem()

for area in pd.unique(df['area']):    
    mu = mu_.loc[area,:,:]
    se = se_.loc[area,:,:]
    
    c  = colors_[colors_["Area"]==area].to_numpy()
    c  = c[0][:3]
    
    c_hsv = list( colorsys.rgb_to_hsv(*c) )
    c_hsv[1] *= 0.5
    c_hsv[2] *= 0.5
    c_dull    = list( colorsys.hsv_to_rgb(*c_hsv) )
    
    fig = go.Figure()
    
    fig.add_trace(go.Bar(
        name='60 neurons',
        marker_color=f'rgb({c[0]},{c[1]},{c[2]})',
        x=[0,1], y=mu['acc'].loc[:,60].to_list(),
        error_y=dict(type='data', array=se['acc'].loc[:,60].to_list())
    ))
    fig.add_trace(go.Bar(
        name='6 neurons',
        marker_color=f'rgb({c_dull[0]},{c_dull[1]},{c_dull[2]})',
        x=[0,1], y=mu['acc'].loc[:,6].to_list(),
        error_y=dict(type='data', array=se['acc'].loc[:,6].to_list())
    ))
    
    obsval = mu['acc'].loc['passive',60] - 2*se['acc'].loc['passive',60]
    actval = mu['acc'].loc['active',6] + 2*se['acc'].loc['active',6]
    print(f'Obs60-2SE = {obsval}')
    print(f'VGG06+2SE = {actval}')

    fig.update_xaxes(ticks='outside',
                               tickwidth=1,
                               tickcolor='black',
                               ticklen=4,
                               linecolor='rgba(0,0,0,1)',
                               linewidth=1,
                               showgrid=False)

    fig.update_yaxes(ticks='outside',
                                   tickwidth=1,
                                   tickcolor='black',
                                   ticklen=4,
                                   linecolor='rgba(0,0,0,1)',
                                   linewidth=1,
                                   showgrid=False
                                   )

    # guess I gotta go low-level for this
    fig['layout']['xaxis']['title'] = 'Context'
    fig['layout']['xaxis']['range'] = [-0.5, 1.5]
    fig['layout']['yaxis']['title'] = f'{area} Grip Classification Accuracy'
    fig['layout']['yaxis']['range'] = [0, 1]
    fig['layout']['xaxis']['ticktext'] = ['VGG','Observation']
    fig['layout']['xaxis']['tickvals'] = [0,1]
    
    # full_fig = fig.full_figure_for_development()
    # print(full_fig.layout.xaxis.range)
    
    # chance is the same regardless of how many neurons were used to classify. So just use the value at "6"
    fig.add_trace(
        go.Scatter(
            x=[-0.5,0.5],
            y=[mu['chance'].loc['active',6] for _ in range(2)],
            name='chance_active',
            mode='lines',
            line={
                'color':f'rgba(0,0,0,0.5)',
                'dash':'dash'
            }
        ),
    )
    
    fig.add_trace(
        go.Scatter(
            x=[0.5,1.5],
            y=[mu['chance'].loc['passive',6] for _ in range(2)],
            name='chance_passive',
            mode='lines',
            line={
                'color':f'rgba(0,0,0,0.5)',
                'dash':'dash'
            }
        ),
    )

    fig.update_layout(barmode='group',
        plot_bgcolor='rgba(0,0,0,0)' ,
        paper_bgcolor='rgba(0,0,0,0)',
        showlegend=False,
        autosize=False,
        width=350,
        height=350)

    # I also need to do janky things to make a custom legend, too! wow!

    colors = [c,c_dull]
    prepend=''
    for idx_,legent in enumerate(['60 Neurons','6 Neurons']):
        c_  = colors[idx_]

        fig.add_annotation(xref='x domain',
                                         yref='y domain',
                                         x = 1,
                                         y = 1,
                                         text = prepend+legent,
                                         showarrow=False,
                                         font={
                                             'color':f'rgb({c_[0]},{c_[1]},{c_[2]})',
                                             'size':14
                                             },
                                         align='right',
                                         valign='top',
                                         yanchor='top',
                                         xanchor='right')

        prepend+=' <br>' # needs a space

    fig.show(renderer="svg")
    fig.write_image(os.path.join('figs',f'{area}_subsampdecoding.svg'))
# Out:
# Obs60-2SE = 0.35146728696402046
# VGG06+2SE = 0.3433503502369949
# Obs60-2SE = 0.245978621046185
# VGG06+2SE = 0.3595609015868218
# Obs60-2SE = 0.1873029576706089
# VGG06+2SE = 0.34800275125550423

# %%
bs_index_list_stratified = []

for a,b in df['session'].value_counts().items():
    data_index_stratum = list(df[df['session'] == a].index)    
    bs_index_list_stratified.extend(choices(data_index_stratum , k = len(data_index_stratum )))

for _ in range(10):
    print(choices(['apple','banana','grape'],k=3))
    
print(bs_index_list_stratified)

print(df.iloc[bs_index_list_stratified])
# Out:
# ['grape', 'grape', 'banana']
# ['apple', 'banana', 'banana']
# ['grape', 'grape', 'apple']
# ['apple', 'banana', 'banana']
# ['apple', 'apple', 'apple']
# ['grape', 'banana', 'banana']
# ['apple', 'banana', 'grape']
# ['apple', 'grape', 'grape']
# ['banana', 'banana', 'banana']
# ['grape', 'banana', 'grape']
# [96, 33, 75, 101, 102, 11, 79, 41, 64, 107, 82, 61, 6, 5, 91, 38, 101, 68, 106, 71, 40, 91, 103, 115, 80, 107, 69, 0, 6, 50, 12, 91, 59, 115, 46, 79, 9, 58, 19, 37, 40, 108, 37, 76, 98, 107, 16, 93, 38, 5, 98, 40, 40, 1, 46, 59, 72, 108, 43, 22, 92, 19, 69, 10, 119, 104, 39, 50, 17, 5, 33, 42, 27, 88, 113, 51, 25, 23, 51, 43, 28, 73, 69, 83, 39, 58, 5, 8, 45, 45, 46, 7, 40, 69, 28, 106, 20, 1, 53, 97, 119, 88, 64, 73, 99, 48, 33, 100, 109, 3, 106, 51, 4, 6, 20, 68, 69, 45, 106, 101, 164, 208, 202, 156, 161, 177, 141, 138, 182, 227, 202, 196, 141, 149, 182, 230, 194, 133, 143, 127, 221, 191, 196, 143, 138, 229, 175, 191, 226, 185, 131, 194, 128, 177, 137, 206, 128, 166, 229, 231, 233, 132, 197, 206, 176, 221, 182, 187, 130, 198, 201, 167, 159, 212, 208, 207, 218, 165, 128, 164, 179, 140, 132, 158, 214, 148, 187, 191, 188, 217, 149, 185, 128, 144, 137, 227, 178, 234, 197, 226, 175, 181, 166, 229, 195, 132, 184, 220, 154, 138, 191, 150, 168, 188, 178, 132, 160, 173, 227, 186, 216, 151, 139, 213, 223, 199, 217, 200, 148, 224, 213, 172, 146, 169, 232, 204, 164, 165, 202, 185, 322, 283, 352, 310, 272, 304, 264, 314, 253, 350, 254, 272, 351, 242, 305, 257, 264, 313, 245, 355, 281, 246, 329, 313, 314, 246, 353, 338, 294, 293, 354, 269, 344, 359, 345, 251, 296, 292, 322, 356, 264, 349, 320, 282, 353, 317, 335, 259, 314, 313, 313, 285, 332, 240, 246, 287, 304, 260, 324, 273, 259, 241, 299, 331, 288, 326, 316, 297, 352, 275, 316, 333, 313, 309, 297, 352, 289, 305, 318, 288, 293, 264, 319, 336, 243, 352, 250, 311, 269, 341, 322, 268, 315, 316, 288, 253, 293, 240, 351, 351, 311, 337, 324, 351, 289, 246, 349, 298, 259, 354, 331, 340, 352, 313, 257, 262, 340, 345, 240, 294, 412, 434, 424, 365, 460, 406, 397, 368, 428, 463, 407, 440, 458, 360, 385, 433, 434, 367, 479, 368, 382, 471, 436, 440, 415, 473, 365, 429, 419, 470, 393, 436, 452, 371, 392, 431, 461, 434, 404, 424, 419, 391, 417, 389, 460, 390, 424, 421, 466, 462, 402, 439, 420, 384, 431, 463, 412, 393, 427, 410, 410, 465, 457, 410, 459, 414, 410, 378, 375, 458, 478, 437, 439, 439, 460, 391, 372, 429, 378, 382, 421, 398, 438, 455, 404, 454, 475, 382, 383, 417, 362, 459, 387, 422, 376, 368, 411, 448, 397, 386, 439, 442, 447, 471, 375, 381, 464, 445, 378, 364, 433, 457, 444, 393, 397, 427, 418, 451, 477, 390]
#           acc    chance session animal area  context  neuroncount
# 96   0.401130  0.220332  Zara64   Zara   M1   active            6
# 33   0.337079  0.168549  Zara64   Zara  AIP  passive           60
# 75   0.314607  0.168549  Zara64   Zara   F5  passive           60
# 101  0.174157  0.168549  Zara64   Zara   M1  passive           60
# 102  0.604520  0.220332  Zara64   Zara   M1   active           60
# ..        ...       ...     ...    ...  ...      ...          ...
# 427  0.253521  0.164326   Moe50    Moe   F5  passive           60
# 418  0.262911  0.225389   Moe50    Moe   F5   active            6
# 451  0.215962  0.164326   Moe50    Moe   M1  passive            6
# 477  0.225352  0.164326   Moe50    Moe   M1  passive           60
# 390  0.732394  0.225389   Moe50    Moe  AIP   active           60
#
# [480 rows x 7 columns]

# %%
import colorsys

rgb = [1,0,0]
hsv = list( colorsys.rgb_to_hsv(*rgb) )
hsv[1] *= 0.5
hsv[2] *= 0.5
rgb_new = list( colorsys.hsv_to_rgb(*hsv) )

print(hsv)
print(rgb_new)

print(truecolors)

q = [rgb,rgb_new]
print(q)
# Out:
# [0.0, 0.5, 0.5]
# [0.5, 0.25, 0.25]
# [['rgba(255, 118, 26, 0.7)', 'rgba(109, 83, 55, 0.7)'], ['rgba(26, 200, 118, 0.7)', 'rgba(55, 109, 83, 0.7)']]
# [[1, 0, 0], [0.5, 0.25, 0.25]]

# %% [markdown]
# # Subspace alignment time (this time we actually do visual space orthogonalization!)
# (active-passive vs. active-baseline)
#
# (shuffle vs. active-active)

# %%
# https://stackoverflow.com/questions/35328198/what-is-stratified-bootstrap
# performs a stratified bootstrap

def stratified_bootstap(bs_sample:pd.DataFrame,
                       labelcol:str):

    strata = bs_sample[labelcol].value_counts()
    bs_index_list_stratified = []

    for idx_stratum_var, n_stratum_var in strata.items():

        data_index_stratum = list(bs_sample[bs_sample[labelcol] == idx_stratum_var].index)
        bs_index_list_stratified.extend(choices(data_index_stratum , k = len(data_index_stratum )))

    return bs_index_list_stratified

# %%
# alignment (todo!)
subaligns = dict()

for session in sessions:
    subaligns[session] = dict()
    
    for area in areas:
        subaligns[session][area] = dict()
        
        dp = DataPartitioner(session=session,
                            areas=[area],
                            aligns=['fixation','cue onset','hold onset'],
                            contexts=['active','passive'],
                            groupings=['context','object','grip','turntable','alignment'])
        
        df = dp.readQuery(0)
        df['turntable'] = df['turntable'] // 10
        
        df_vision_trials   = df[(df['alignment']=='cue onset') & (df['time']>0)].groupby(['context','object','trial'],sort=False).aggregate('mean').reset_index()
        df_movement_trials = df[(df['alignment']=='hold onset') & (df['time']<0)].groupby(['context','grip','trial'],sort=False).aggregate('mean').reset_index()
        df_baseline_trials = df[(df['alignment']=='fixation') & (df['time']<0)].groupby(['context','grip','trial'],sort=False).aggregate('mean').reset_index()
        
        # okay, let's iterate through contexts
        for versus in ['passive','baseline','active']:
            print(f"{session} {area} active vs. {versus}")
            subaligns[session][area][versus] = list()
            
            df_active = df_movement_trials.loc[
                (df_movement_trials['context']=='active')].reset_index()
            
            if versus=='passive':
                df_versus = df_movement_trials.loc[
                    (df_movement_trials['context']=='passive')].reset_index()
            elif versus=='baseline':
                df_versus = df_baseline_trials.loc[
                    (df_baseline_trials['context']=='active')].reset_index()
            else:
                gripnames = df_active['grip'].unique()
                halflen   = len(gripnames)//2
                df_versus = df_active.loc[df_active['grip'].isin(gripnames[:halflen])].reset_index()
                df_active = df_active.loc[df_active['grip'].isin(gripnames[halflen:])].reset_index()
                
            # ehhh don't bother cross-validating though. Bootstrap instead!
            for bootstrapidx in range(10):
                visidx    = stratified_bootstap(bs_sample=df_vision_trials,labelcol='object')
                actidx    = stratified_bootstap(bs_sample=df_active,labelcol='grip')
                versusidx = stratified_bootstap(bs_sample=df_versus,labelcol='grip')
                    
                df_vision_ = df_vision_trials.iloc[visidx].groupby(['object'])[dp.get('neuronColumnNames')].mean()
                
                # compute class means as we're looking for overlap of grip-coding spaces
                df_active_ = df_active.iloc[actidx].groupby(['grip'])[dp.get('neuronColumnNames')].mean()
                df_versus_ = df_versus.iloc[versusidx].groupby(['grip'])[dp.get('neuronColumnNames')].mean()
                
                ocount     = orthocounts[session][area]
                
                PCmdl      = PCA()
                PCmdl.fit(df_vision_.to_numpy())
                
                visspace   = PCmdl.components_[:ocount,:]
                
                if ocount > 0:
                    visnull    = null_space(np.matrix(visspace))
                else:
                    visnull    = np.eye(len(dp.get('neuronColumnNames')))
                    
                Xactive = df_active_.to_numpy() @ visnull
                Xversus = df_versus_.to_numpy() @ visnull
                
                ncompsa  = min(Xactive.shape[0]-1,10)
                ncompsv  = min(Xversus.shape[0]-1,10)
                PCactive = PCA(n_components=ncompsa)
                PCversus = PCA(n_components=ncompsv)
                
                Xactive_selfproj = PCactive.fit_transform(Xactive)
                Xversus_selfproj = PCversus.fit_transform(Xversus)
                
                Xactive_crossproj = PCversus.transform(Xactive)
                Xversus_crossproj = PCactive.transform(Xversus)
                
                # compute an alignment index
                align_index_num   = np.sum( np.var(Xactive_crossproj,axis=0) ) + np.sum( np.var(Xversus_crossproj,axis=0) )
                align_index_denom = np.sum( np.var(Xactive_selfproj,axis=0) ) + np.sum( np.var(Xversus_selfproj,axis=0) )
                align_index       = align_index_num / align_index_denom
                
                subaligns[session][area][versus] += [align_index]

                print(f"    Remaining axes = active: {ncompsa}, versus: {ncompsv}")
                print(f"    Number of neurons = {len(dp.get('neuronColumnNames'))}")
                print(f"    Alignment Index = {align_index}")
                print()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Zara64 AIP active vs. passive
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.11497134070844348
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.10134148714447155
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.09763644706641385
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.10588165258252998
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.12091645708256371
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.12379266149611969
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.1072586136609975
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.11331015162262156
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.1290257942417017
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.12762572737227781
#
# Zara64 AIP active vs. baseline
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.10187376917559278
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.10221060007293015
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.0915038571513969
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.08298971942388877
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.10406248723128265
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.08492074332957707
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.1048996750739087
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.12946161858062122
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.09568658674838953
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.11220607324146324
#
# Zara64 AIP active vs. active
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.1148581614637041
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2015836848319808
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.1244326307221109
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.19164327018817368
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.21328532112227638
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.15055196784462932
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.18393992033590256
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.1419612526833581
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.17770788778391766
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.17433590383788833
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Zara64 F5 active vs. passive
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.15622587850997943
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.13876022244797198
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.152528792967184
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.12294139572661049
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.13078760260184433
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.12620254696567645
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.15453976834660024
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.15669062638541184
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.13626448942299094
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.13537725953426274
#
# Zara64 F5 active vs. baseline
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.08112748596702096
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.09263702570511041
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.06477185149167937
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.07183569972085795
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.07311988545578968
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.08616213638372694
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.07782344849704761
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.1099528933093536
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.0858202945325741
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 121
#     Alignment Index = 0.05981977096823057
#
# Zara64 F5 active vs. active
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.32574202407112657
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2943224344382295
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.323012611717481
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.3436612413438176
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2747363347299342
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2911022757750504
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.29528935053369926
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.26716397753188154
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.3564387638142868
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.3097992265256959
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Zara64 M1 active vs. passive
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.1489976063263587
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.15836332930527552
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.16621447851505183
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.14716287431652697
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.13134435717844697
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.16301961345795563
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.15879715619652535
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.13723058377436403
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.15696737801652624
#
#     Remaining axes = active: 9, versus: 10
#     Number of neurons = 99
#     Alignment Index = 0.16097518663198382
#
# Zara64 M1 active vs. baseline
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.10239508357870424
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.08895037965051346
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.13074753320482418
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.10625673389562912
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.0724975680809511
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.10209798747425601
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.08721316225181366
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.09535140735674556
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.07439222797222998
#
#     Remaining axes = active: 9, versus: 9
#     Number of neurons = 99
#     Alignment Index = 0.08947207323680241
#
# Zara64 M1 active vs. active
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.41899176569036944
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.4334050501780829
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.48516770443880636
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.46268779757415374
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.4290043616172959
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.44233586626641364
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.4394295743051724
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.43396425884865475
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.4361033978985955
#
#     Remaining axes = active: 4, versus: 4
#     Number of neurons = 99
#     Alignment Index = 0.41932054694641524
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Zara70 AIP active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.088171638088171
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.11715505025252218
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.1132290339740887
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.11120345566237651
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.10101160296959637
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.08527269081113456
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.12299591883906473
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.0917760637587209
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.08883671138941417
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.09557055633540677
#
# Zara70 AIP active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.09320220147684237
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.10349690994470791
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.09359674583258058
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.07253173405003754
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.13330936186639383
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.09346526337319401
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.10882974280526685
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.09701196722150815
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.0756139451703773
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 121
#     Alignment Index = 0.10921462957255654
#
# Zara70 AIP active vs. active
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.27949805917097736
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.26105188064587176
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.3335713622089131
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2830434414797302
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.25440609370774525
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2844723603080185
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2890281890707955
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.2760806707086007
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.28112440351412427
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 121
#     Alignment Index = 0.22283295622469426
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Zara70 F5 active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.1708918279090708
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.12785644326748605
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.20301173162365177
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.15416740233923054
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.16198022851165633
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.16553290443406932
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.17557049081873405
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.17290816679416973
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.1568078006508343
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.1172949833658507
#
# Zara70 F5 active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.10754401604133075
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.10905677192106109
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.10630141999860047
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.10695106179667449
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.11201787674662518
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.11229885778938622
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.11657227446065957
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.108727986713343
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.10351985721660667
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 108
#     Alignment Index = 0.12015526839601579
#
# Zara70 F5 active vs. active
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.3419221324892382
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.3248176341546321
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.33408798693913805
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.34957953783106427
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.350660336691459
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.3661841737543473
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.3245869913375807
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.4114458107375453
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.32708355676707684
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 108
#     Alignment Index = 0.33812371111026734
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Zara70 M1 active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07425885466678488
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.062227849074718594
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.08409546415894803
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07653511326926668
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07782597389111702
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07006897934284964
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07664092385513566
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.06975512924076746
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07309501123447548
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07852463092554417
#
# Zara70 M1 active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.06827016069073155
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07266286176976842
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.06651863421652225
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.08458618143826101
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.08602243483529244
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.06344705765934236
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07414405352986705
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.08757610599111205
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07504679533208587
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 183
#     Alignment Index = 0.07883213515633009
#
# Zara70 M1 active vs. active
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.3679238756694724
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.426584212079605
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.4259253105286258
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.3700789176105813
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.42499102179194903
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.37131190374815704
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.4484201108558374
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.3648234622160461
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.4240822761501609
#
#     Remaining axes = active: 5, versus: 4
#     Number of neurons = 183
#     Alignment Index = 0.39228537604004193
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Moe46 AIP active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.13188312382506392
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.1513607519292896
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.16074824055040585
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.16295508949369877
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.13177813135506752
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.15080357142017448
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.15103599216238717
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.13718903999227475
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.13938359910666714
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.1380536357219266
#
# Moe46 AIP active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.16336581650265108
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.12263333663677894
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.1559229671021536
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.15960388582690813
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.14198612094238983
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.1543913910786841
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.14587489030180384
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.1438990481489679
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.13936657196832244
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 102
#     Alignment Index = 0.17216380335335033
#
# Moe46 AIP active vs. active
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.22231684316476127
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.22754238121362058
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.25135603496369424
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.2184994146825261
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.21022137731664092
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.18929210485029366
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.2370303039415326
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.26928617422435575
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.2610953148108985
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 102
#     Alignment Index = 0.23749034313612633
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Moe46 F5 active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.0757366466007645
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.07739557665877425
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.06850891833172944
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.06367068596756181
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.04461132203595199
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.06179685862048054
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.060592186495100904
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.06316844827761624
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.05842866359286109
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.058222189536120864
#
# Moe46 F5 active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.10446565341202832
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.0788707682372647
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.06212598348778114
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.09334393590175605
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.08952260534704158
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.08496123076597095
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.1053608371933112
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.09742002069344045
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.10714763881608622
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 191
#     Alignment Index = 0.0927720417416547
#
# Moe46 F5 active vs. active
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.31161927711662024
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.29214857941143163
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.32523873311756785
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.3008465882387954
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.29880305828359965
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.28189784126204076
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.3143136114797253
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.28904140946815765
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.2772978117747764
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 191
#     Alignment Index = 0.3105299951932506
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Moe46 M1 active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.08365458670892824
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.0818391505604603
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.08200305545056581
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06785416032835748
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06634678263254412
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.08352735726938423
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.07872476683058792
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06775830218674465
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06716531007817675
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.05922377385294215
#
# Moe46 M1 active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.0752213727764939
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.091408194846228
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.05901214048676472
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06741886411163797
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06726929925374316
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.07836758815230982
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.08019848465789942
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.08953365968422479
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.07791040288908915
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 149
#     Alignment Index = 0.06706386176187394
#
# Moe46 M1 active vs. active
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.32712853877847003
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.35655441911735325
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.38252404033033066
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.3767363802385003
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.3367909103628117
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.32256190853750394
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.37082556560625074
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.3886160479353389
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.34764252540866686
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 149
#     Alignment Index = 0.3106936929397741
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Moe50 AIP active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.25620680495498227
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.27093379285809793
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.2926041532712837
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.2507843218707306
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.3169912261697652
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.24691565427850817
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.2165488812052436
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.28678944425034597
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.2755172221725294
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.24131718000087465
#
# Moe50 AIP active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.169311432383142
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.18530098096894682
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.20804107257728421
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.19623006539268087
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.2118802068303084
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.23834751365086104
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.1833499605810306
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.19267887053484611
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.18543104555299214
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 67
#     Alignment Index = 0.21020900580728427
#
# Moe50 AIP active vs. active
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.3846682135348409
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.25822368156271447
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.2558049397739671
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.38862116141799574
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.29918306535403605
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.311958117248793
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.30721082641583103
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.33266698657227345
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.29964223877465745
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 67
#     Alignment Index = 0.2990502304691403
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Moe50 F5 active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.06438998701630139
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.050141321337050244
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.06038296762104884
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.05683933644802243
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.06324571023116098
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.0522208162181475
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.052938673530445304
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.06783571997379666
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.054624026662592445
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.05734484550885978
#
# Moe50 F5 active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.052144840360649425
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.04311254442171088
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.047967477851292024
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.04657942571132431
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.04504763797495916
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.038874833901249475
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.049158032816837435
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.055167020426905515
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.04382249841550756
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 206
#     Alignment Index = 0.04411932557729254
#
# Moe50 F5 active vs. active
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.24012852144267474
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.23992456798939207
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.2591311869638014
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.25427999362334297
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.22233532713817755
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.2332969417252307
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.20003024000550654
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.24839074142236878
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.257131508094971
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 206
#     Alignment Index = 0.2533697295240655
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:19: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:20: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_3456\653121031.py:21: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Moe50 M1 active vs. passive
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.12001594638689221
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.13744277826432022
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.12863319373434928
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.13086408249524364
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.14657531156924125
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.1401969642208907
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.16748585194513313
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.1391017023990962
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.15541813576768115
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.14363657857673245
#
# Moe50 M1 active vs. baseline
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.15712259535832118
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.1666780274882669
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.17084997206900573
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.16694024878530012
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.15127720126047584
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.15340028006693296
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.16851141924871904
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.12413343087592474
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.1509939604654626
#
#     Remaining axes = active: 10, versus: 10
#     Number of neurons = 164
#     Alignment Index = 0.14928736356722735
#
# Moe50 M1 active vs. active
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.20797021292679582
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.2379472114167297
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.25901748733703567
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.24530165442749138
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.2114986722309079
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.2122704180358266
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.2325257195914501
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.24809026258137457
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.24401655681343412
#
#     Remaining axes = active: 5, versus: 5
#     Number of neurons = 164
#     Alignment Index = 0.19596963820027333

# %%
# process into dataframe
# prep the data for plotting

# get the data ready for plotting
# active-6 | active-60 | passive-6 | passive-60
# for each area

alignment_index = []
session_ = []
animal_ = []
area_ = []
versus_ = []

for session in subaligns:
    for area in subaligns[session]:
        for versus in subaligns[session][area]:
            for boot in subaligns[session][area][versus]:
                alignment_index += [boot]
                session_ += [session]

                an,_ = mysplit(session)
                animal_  += [an]

                area_    += [area]
                versus_  += [versus]

dd = {'alignment_index':alignment_index,
      'session':session_,
      'animal':animal_,
      'area':area_,
      'versus':versus_}

df = pd.DataFrame(dd)

print(df)

fname = os.path.join('pythonfigures','subspace_aligns.json')
df.to_json(fname) # to sql was probably better...

mu = df.groupby(['area','versus'])[['alignment_index']].mean()
se = df.groupby(['area','versus'])[['alignment_index']].sem()
print(mu)
print(se)
# Out:
#      alignment_index session animal area   versus
# 0           0.114971  Zara64   Zara  AIP  passive
# 1           0.101341  Zara64   Zara  AIP  passive
# 2           0.097636  Zara64   Zara  AIP  passive
# 3           0.105882  Zara64   Zara  AIP  passive
# 4           0.120916  Zara64   Zara  AIP  passive
# ..               ...     ...    ...  ...      ...
# 355         0.212270   Moe50    Moe   M1   active
# 356         0.232526   Moe50    Moe   M1   active
# 357         0.248090   Moe50    Moe   M1   active
# 358         0.244017   Moe50    Moe   M1   active
# 359         0.195970   Moe50    Moe   M1   active
#
# [360 rows x 5 columns]
#                alignment_index
# area versus
# AIP  active           0.247514
#      baseline         0.136752
#      passive          0.156670
# F5   active           0.298988
#      baseline         0.082205
#      passive          0.105711
# M1   active           0.355788
#      baseline         0.100477
#      passive          0.110489
#                alignment_index
# area versus
# AIP  active           0.010095
#      baseline         0.007016
#      passive          0.010730
# F5   active           0.007006
#      baseline         0.004045
#      passive          0.007652
# M1   active           0.013277
#      baseline         0.005627
#      passive          0.006082

# %%
# grouped barplot
# bar plots!
fname   = os.path.join('pythonfigures','subspace_aligns.json')
df      = pd.read_json(fname)
colors_ = pd.read_csv(os.path.join('pythonfigures','colors.csv'))

mu_ = df.groupby(['area','versus'])[['alignment_index']].mean()
se_ = df.groupby(['area','versus'])[['alignment_index']].sem()

fig = go.Figure()

for area in ['AIP','F5','M1']:
    c  = colors_[colors_["Area"]==area].to_numpy()
    c  = c[0][:3]
    fig.add_trace(go.Bar(
        name=area,
        marker_color=f'rgb({c[0]},{c[1]},{c[2]})',
        x=[0,1,2], y=mu_['alignment_index'].loc[area,['active','passive','baseline']].to_list(),
        error_y=dict(type='data', array=se_['alignment_index'].loc[area,['active','passive','baseline']].to_list())
    ))
    
fig.update_xaxes(ticks='outside',
                           tickwidth=1,
                           tickcolor='black',
                           ticklen=4,
                           linecolor='rgba(0,0,0,1)',
                           linewidth=1,
                           showgrid=False)

fig.update_yaxes(ticks='outside',
                           tickwidth=1,
                           tickcolor='black',
                           ticklen=4,
                           linecolor='rgba(0,0,0,1)',
                           linewidth=1,
                           showgrid=False
                           )

# guess I gotta go low-level for this
fig['layout']['xaxis']['title'] = 'Context aligned to VGG'
fig['layout']['xaxis']['range'] = [-0.5, 2.5]
fig['layout']['yaxis']['title'] = 'Subspace Alignment Index'
fig['layout']['yaxis']['range'] = [0, 0.5]
fig['layout']['xaxis']['ticktext'] = ['VGG','Observation','Baseline']
fig['layout']['xaxis']['tickvals'] = [0,1,2]

fig.update_layout(barmode='group',
    plot_bgcolor='rgba(0,0,0,0)' ,
    paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    autosize=False,
    width=400,
    height=400)

# I also need to do janky things to make a custom legend, too! wow!

colors = [c,c_dull]
prepend=''
for idx_,legent in enumerate(['AIP','F5','M1']):
    c_  = colors_[colors_["Area"]==legent].to_numpy()
    c_  = c_[0][:3]

    fig.add_annotation(xref='x domain',
                                     yref='y domain',
                                     x = 1,
                                     y = 1,
                                     text = prepend+legent,
                                     showarrow=False,
                                     font={
                                         'color':f'rgb({c_[0]},{c_[1]},{c_[2]})',
                                         'size':14
                                         },
                                     align='right',
                                     valign='top',
                                     yanchor='top',
                                     xanchor='right')

    prepend+=' <br>' # needs a space

fig.show(renderer="svg")
fig.write_image(os.path.join('figs','subspacealign.svg'))

# %%
colors_ = pd.read_csv(os.path.join('pythonfigures','colors.csv'))
print(colors_)
# Out:
#      R    G    B Area
# 0  125   46  141  AIP
# 1  226  129   28   F5
# 2    0  113  188   M1

# %%
fname   = os.path.join('pythonfigures','subspace_aligns.json')
df      = pd.read_json(fname)
colors_ = pd.read_csv(os.path.join('pythonfigures','colors.csv'))

mu_ = df.groupby(['area','versus'])[['alignment_index']].mean()
se_ = df.groupby(['area','versus'])[['alignment_index']].sem()

print(mu_)
print(mu['alignment_index'].loc[area,:])
print(mu_['alignment_index'].loc[area,['active','passive','baseline']])
# Out:
#                alignment_index
# area versus
# AIP  active           0.247514
#      baseline         0.136752
#      passive          0.156670
# F5   active           0.298988
#      baseline         0.082205
#      passive          0.105711
# M1   active           0.355788
#      baseline         0.100477
#      passive          0.110489
# versus
# active      0.355788
# baseline    0.100477
# passive     0.110489
# Name: alignment_index, dtype: float64
# area  versus
# M1    active      0.355788
#       passive     0.110489
#       baseline    0.100477
# Name: alignment_index, dtype: float64

# %%
gripnames = df_active['grip'].unique()
halflen   = len(gripnames)//2
df_active[df_active['grip'].isin(gripnames[:halflen])]
# Out:
#      level_0  index context  grip  trial        n0        n1            n2  \
# 0          1      1  active     7     62  0.378152  0.417521  0.000000e+00
# 1          3      3  active     3     64  0.677090  0.655575  2.762944e-01
# 2          5      5  active    11     66  0.556368  0.120310  3.934257e-01
# 3          6      6  active     7     67  0.276914  0.449390  2.032485e-01
# 4          8      8  active     3     69  0.424996  0.399984  2.447322e-02
# ..       ...    ...     ...   ...    ...       ...       ...           ...
# 132      230    408  active     7    469  0.215935  0.455413  1.093260e-02
# 134      232    410  active    11    471  0.294266  0.158729  1.300725e-01
# 135      233    411  active    11    472  0.181799  0.316194  1.217292e-06
# 136      234    412  active     7    473  0.122507  0.148835  0.000000e+00
# 137      235    413  active    11    474  0.331583  0.161615  1.216845e-07
#
#            n3        n4  ...      n100      n101  n102  n103      n104  \
# 0    0.361147  0.000003  ...  0.000000  0.137015   0.0   0.0  0.000000
# 1    0.353780  0.104207  ...  0.004347  0.145421   0.0   0.0  0.000000
# 2    0.592615  0.000000  ...  0.070556  0.000000   0.0   0.0  0.028585
# 3    0.324328  0.000000  ...  0.000000  0.141643   0.0   0.0  0.000168
# 4    0.286887  0.028615  ...  0.000000  0.000098   0.0   0.0  0.000000
# ..        ...       ...  ...       ...       ...   ...   ...       ...
# 132  0.336687  0.000001  ...  0.000000  0.144911   0.0   0.0  0.000000
# 134  0.450783  0.000000  ...  0.121216  0.259182   0.0   0.0  0.000000
# 135  0.562508  0.022071  ...  0.472527  0.300281   0.0   0.0  0.000000
# 136  0.413115  0.000000  ...  0.000000  0.000000   0.0   0.0  0.000000
# 137  0.519716  0.084530  ...  0.000000  0.239928   0.0   0.0  0.000000
#
#              n105      n106      n107  turntable   time
# 0    1.281261e-07  0.445181  0.000000        1.0 -250.0
# 1    0.000000e+00  0.276775  0.180935        1.0 -250.0
# 2    1.552797e-01  0.133103  0.196756        1.0 -250.0
# 3    0.000000e+00  0.000009  0.129139        1.0 -250.0
# 4    0.000000e+00  0.266085  0.000000        1.0 -250.0
# ..            ...       ...       ...        ...    ...
# 132  0.000000e+00  0.009593  0.000000        4.0 -250.0
# 134  7.275013e-02  0.107363  0.000000        4.0 -250.0
# 135  7.272615e-02  0.248799  0.000000        4.0 -250.0
# 136  0.000000e+00  0.133459  0.000000        4.0 -250.0
# 137  0.000000e+00  0.494338  0.113998        4.0 -250.0
#
# [98 rows x 115 columns]

# %% [markdown]
# # Appendix: ChatGPT-generated barplot

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[
    go.Bar(name='Hello', x=['Hello'], y=[5], error_y=dict(type='data', array=[1], color='midnightblue'), marker_color='midnightblue'),
    go.Bar(name='World', x=['World'], y=[4], error_y=dict(type='data', array=[2], color='hotpink'), marker_color='hotpink'),
    go.Bar(name='Foo', x=['Foo'], y=[3], error_y=dict(type='data', array=[1], color='darkred'), marker_color='darkred')
])

fig.update_layout(title='dog water', xaxis_title='Labels', yaxis_title='dog water')

fig.show(renderer="svg")
